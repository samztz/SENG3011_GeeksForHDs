# %% [markdown]
# # Step 1: Getting data from API and converting in Appropriate structure

# %%
#import api data
import requests
url= 'https://api.covidactnow.org/v2/counties.json?apiKey=6abf0fcadd5d4ddab5f43d619f68871e'
resp = requests.get(url=url).json()

# %%
#check responce
resp[61]
# Out:
# {'fips': '01065',
#  'country': 'US',
#  'state': 'AL',
#  'county': 'Hale County',
#  'hsa': '156',
#  'hsaName': 'Tuscaloosa (Tuscaloosa), AL - Pickens, AL',
#  'level': 'county',
#  'lat': None,
#  'locationId': 'iso1:us#iso2:us-al#fips:01065',
#  'long': None,
#  'population': 14651,
#  'hsaPopulation': 252047,
#  'metrics': {'testPositivityRatio': 0.017,
#   'testPositivityRatioDetails': {'source': 'other'},
#   'caseDensity': 9.3,
#   'weeklyNewCasesPer100k': 64.8,
#   'contactTracerCapacityRatio': None,
#   'infectionRate': 1.11,
#   'infectionRateCI90': 1.1,
#   'icuCapacityRatio': None,
#   'bedsWithCovidPatientsRatio': 0.0,
#   'weeklyCovidAdmissionsPer100k': 0.8,
#   'vaccinationsInitiatedRatio': 0.727,
#   'vaccinationsCompletedRatio': 0.613,
#   'vaccinationsAdditionalDoseRatio': 0.249},
#  'riskLevels': {'overall': 2,
#   'testPositivityRatio': 0,
#   'caseDensity': 1,
#   'contactTracerCapacityRatio': 4,
#   'infectionRate': 2,
#   'icuCapacityRatio': 4},
#  'cdcTransmissionLevel': 2,
#  'communityLevels': {'cdcCommunityLevel': 0, 'canCommunityLevel': 0},
#  'actuals': {'cases': 4716,
#   'deaths': 106,
#   'positiveTests': None,
#   'negativeTests': None,
#   'contactTracers': None,
#   'hospitalBeds': {'capacity': 21,
#    'currentUsageTotal': 6,
#    'currentUsageCovid': 1,
#    'weeklyCovidAdmissions': 6},
#   'hsaHospitalBeds': {'capacity': 546,
#    'currentUsageTotal': 326,
#    'currentUsageCovid': 2,
#    'weeklyCovidAdmissions': 4},
#   'icuBeds': {'capacity': None,
#    'currentUsageTotal': None,
#    'currentUsageCovid': None},
#   'hsaIcuBeds': {'capacity': 58,
#    'currentUsageTotal': 43,
#    'currentUsageCovid': 1},
#   'newCases': 0,
#   'newDeaths': 0,
#   'vaccinesDistributed': None,
#   'vaccinationsInitiated': 10652,
#   'vaccinationsCompleted': 8987,
#   'vaccinationsAdditionalDose': 3643,
#   'vaccinesAdministered': 19466,
#   'vaccinesAdministeredDemographics': None,
#   'vaccinationsInitiatedDemographics': {'age': {'0-17': 506,
#     '12-17': 522,
#     '16-54': 2027,
#     '18-24': 626,
#     '18-29': 922,
#     '25-49': 2663,
#     '30-49': 2061,
#     '5-11': 175,
#     '50-64': 2483,
#     '55-64': 1399,
#     '65-74': 1588,
#     '75_plus': 1084},
#    'race': {'ai_an': 8,
#     'asian': 21,
#     'black': 5042,
#     'multiple': 582,
#     'other': 84,
#     'pacific_islander': 2,
#     'unknown': 230,
#     'white': 2840},
#    'ethnicity': None,
#    'sex': {'female': 5165, 'male': 3968, 'unknown': 8}}},
#  'annotations': {'cases': {'sources': [{'type': 'NYTimes',
#      'url': 'https://github.com/nytimes/covid-19-data',
#      'name': 'The New York Times'}],
#    'anomalies': []},
#   'deaths': {'sources': [{'type': 'NYTimes',
#      'url': 'https://github.com/nytimes/covid-19-data',
#      'name': 'The New York Times'}],
#    'anomalies': []},
#   'positiveTests': None,
#   'negativeTests': None,
#   'contactTracers': None,
#   'hospitalBeds': {'sources': [{'type': 'other',
#      'url': 'https://healthdata.gov/Hospital/COVID-19-Reported-Patient-Impact-and-Hospital-Capa/anag-cw7u',
#      'name': 'Department of Health and Human Services'}],
#    'anomalies': []},
#   'hsaHospitalBeds': None,
#   'icuBeds': None,
#   'hsaIcuBeds': None,
#   'newCases': None,
#   'newDeaths': None,
#   'vaccinesDistributed': None,
#   'vaccinationsInitiated': {'sources': [{'type': 'other',
#      'url': 'https://data.cdc.gov/Vaccinations/COVID-19-Vaccinations-in-the-United-States-County/8xkx-amqh',
#      'name': 'Centers for Disease Control and Prevention'}],
#    'anomalies': []},
#   'vaccinationsCompleted': {'sources': [{'type': 'other',
#      'url': 'https://data.cdc.gov/Vaccinations/COVID-19-Vaccinations-in-the-United-States-County/8xkx-amqh',
#      'name': 'Centers for Disease Control and Prevention'}],
#    'anomalies': []},
#   'vaccinationsAdditionalDose': {'sources': [{'type': 'other',
#      'url': 'https://data.cdc.gov/Vaccinations/COVID-19-Vaccinations-in-the-United-States-County/8xkx-amqh',
#      'name': 'Centers for Disease Control and Prevention'}],
#    'anomalies': []},
#   'vaccinesAdministered': {'sources': [{'type': 'CANScrapersStateProviders',
#      'url': 'https://alpublichealth.maps.arcgis.com/apps/opsdashboard/index.html#/e4a232feb1344ce0afd9ac162f3ac4ba',
#      'name': 'Alabama Department of Public Health'}],
#    'anomalies': []},
#   'testPositivityRatio': {'sources': [{'type': 'other',
#      'url': 'https://data.cdc.gov/Public-Health-Surveillance/United-States-COVID-19-County-Level-of-Community-T/8396-v7yb',
#      'name': 'Centers for Disease Control and Prevention'}],
#    'anomalies': []},
#   'caseDensity': {'sources': [{'type': 'NYTimes',
#      'url': 'https://github.com/nytimes/covid-19-data',
#      'name': 'The New York Times'}],
#    'anomalies': []},
#   'weeklyNewCasesPer100k': {'sources': [{'type': 'NYTimes',
#      'url': 'https://github.com/nytimes/covid-19-data',
#      'name': 'The New York Times'}],
#    'anomalies': []},
#   'contactTracerCapacityRatio': None,
#   'infectionRate': {'sources': [{'type': 'NYTimes',
#      'url': 'https://github.com/nytimes/covid-19-data',
#      'name': 'The New York Times'}],
#    'anomalies': []},
#   'infectionRateCI90': {'sources': [{'type': 'NYTimes',
#      'url': 'https://github.com/nytimes/covid-19-data',
#      'name': 'The New York Times'}],
#    'anomalies': []},
#   'icuCapacityRatio': None,
#   'bedsWithCovidPatientsRatio': {'sources': [{'type': 'other',
#      'url': 'https://healthdata.gov/Hospital/COVID-19-Reported-Patient-Impact-and-Hospital-Capa/anag-cw7u',
#      'name': 'Department of Health and Human Services'}],
#    'anomalies': []},
#   'weeklyCovidAdmissionsPer100k': {'sources': [{'type': 'other',
#      'url': 'https://healthdata.gov/Hospital/COVID-19-Reported-Patient-Impact-and-Hospital-Capa/anag-cw7u',
#      'name': 'Department of Health and Human Services'}],
#    'anomalies': []},
#   'vaccinationsInitiatedRatio': None,
#   'vaccinationsCompletedRatio': None,
#   'vaccinationsAdditionalDoseRatio': None},
#  'lastUpdatedDate': '2022-04-18',
#  'url': 'https://covidactnow.org/us/alabama-al/county/hale_county'}

# %%
#get fips and other relevant attributes from the api
for i in resp:
     val = i['riskLevels']['overall']
     fips_c = i['fips']
     inf = i['metrics']['infectionRate']
     county = i['county']
     state = i['state']
     coun = i['county']
     vac = i['metrics']['vaccinationsInitiatedRatio']
     i.clear()
     i['fips'] = fips_c
     i['risk'] = val
     i['infectionRate'] = inf
     i['county'] = county
     i['vaccinationsInitiatedRatio'] = vac

# %%
resp[1]
# Out:
# {'fips': '02016',
#  'risk': 1,
#  'infectionRate': 1.0,
#  'county': 'Aleutians West Census Area',
#  'vaccinationsInitiatedRatio': 0.746}

# %%
#output data without hospitals file
import json
with open('datawithoutHos.json', 'w') as f:
    json.dump(resp, f)

# %% [markdown]
# # Step 2: Refine hospital data from different source

# %%
#import health data
dataH = json.load(open('dataMapHealth.json'))
dataH = dataH['features']

# %%
#refine data
resultArray = []
for i in dataH:
    my_dict = i['properties']
    del my_dict['State']
    del my_dict['County Name']
    del my_dict['ICU Bed Source']
    del my_dict['ICU Bed Source Last Updated']
    my_dict['fips'] = my_dict.pop('fips_code')
    data = i['properties']
    resultArray.append(data)

# %%
#hospital json file
import json
with open('hospital2.json', 'w') as f:
    json.dump(resultArray, f)

# %% [markdown]
# # Step 3 Join datas from both sources with fips code as reference

# %%
#import health data
dataR = json.load(open('datawithoutHos.json'))
#import health data
dataH = json.load(open('hospital2.json'))

# %%
import pandas as pd
dr = pd.DataFrame(dataR)
dh = pd.DataFrame(dataH)

# %%
dataH
# Out:
# [{'Staffed All Beds': 55.0,
#   'Staffed ICU Beds': 6.0,
#   'Licensed All Beds': 85.0,
#   'All Bed Occupancy Rate': 0.62,
#   'ICU Bed Occupancy Rate': 0.53,
#   'Population': 55601.0,
#   'Population (20+)': 41177.0,
#   'Population (65+)': 8653.0,
#   'Staffed All Beds [Per 1000 People]': 0.989,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.336,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 6.356,
#   'Staffed ICU Beds [Per 1000 People]': 0.108,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.146,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.693,
#   'Licensed All Beds [Per 1000 People]': 1.529,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.064,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 9.823,
#   'fips': '01001'},
#  {'Staffed All Beds': 25.0,
#   'Staffed ICU Beds': 6.0,
#   'Licensed All Beds': 25.0,
#   'All Bed Occupancy Rate': 0.5,
#   'ICU Bed Occupancy Rate': 0.34,
#   'Population': 57840.0,
#   'Population (20+)': 43175.0,
#   'Population (65+)': 10548.0,
#   'Staffed All Beds [Per 1000 People]': 0.432,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 0.579,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 2.37,
#   'Staffed ICU Beds [Per 1000 People]': 0.104,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.139,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.569,
#   'Licensed All Beds [Per 1000 People]': 0.432,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 0.579,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 2.37,
#   'fips': '01009'},
#  {'Staffed All Beds': 0.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 115.0,
#   'All Bed Occupancy Rate': None,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 33615.0,
#   'Population (20+)': 25934.0,
#   'Population (65+)': 6562.0,
#   'Staffed All Beds [Per 1000 People]': 0.0,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 People]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Licensed All Beds [Per 1000 People]': 3.421,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.434,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 17.525,
#   'fips': '01017'},
#  {'Staffed All Beds': 26.0,
#   'Staffed ICU Beds': 6.0,
#   'Licensed All Beds': 30.0,
#   'All Bed Occupancy Rate': 0.28,
#   'ICU Bed Occupancy Rate': 0.09,
#   'Population': 44153.0,
#   'Population (20+)': 32683.0,
#   'Population (65+)': 7411.0,
#   'Staffed All Beds [Per 1000 People]': 0.589,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 0.796,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 3.508,
#   'Staffed ICU Beds [Per 1000 People]': 0.136,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.184,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.81,
#   'Licensed All Beds [Per 1000 People]': 0.679,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 0.918,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 4.048,
#   'fips': '01021'},
#  {'Staffed All Beds': 300.0,
#   'Staffed ICU Beds': 22.0,
#   'Licensed All Beds': 383.0,
#   'All Bed Occupancy Rate': 0.3,
#   'ICU Bed Occupancy Rate': 0.33,
#   'Population': 54762.0,
#   'Population (20+)': 42196.0,
#   'Population (65+)': 10914.0,
#   'Staffed All Beds [Per 1000 People]': 5.478,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 7.11,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 27.488,
#   'Staffed ICU Beds [Per 1000 People]': 0.402,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.521,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 2.016,
#   'Licensed All Beds [Per 1000 People]': 6.994,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 9.077,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 35.093,
#   'fips': '01033'},
#  {'Staffed All Beds': 77.0,
#   'Staffed ICU Beds': 6.0,
#   'Licensed All Beds': 89.0,
#   'All Bed Occupancy Rate': 0.28,
#   'ICU Bed Occupancy Rate': 0.24,
#   'Population': 48956.0,
#   'Population (20+)': 36652.0,
#   'Population (65+)': 8270.0,
#   'Staffed All Beds [Per 1000 People]': 1.573,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.101,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 9.311,
#   'Staffed ICU Beds [Per 1000 People]': 0.123,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.164,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.726,
#   'Licensed All Beds [Per 1000 People]': 1.818,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.428,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 10.762,
#   'fips': '01045'},
#  {'Staffed All Beds': 70.0,
#   'Staffed ICU Beds': 5.0,
#   'Licensed All Beds': 129.0,
#   'All Bed Occupancy Rate': 0.33,
#   'ICU Bed Occupancy Rate': 0.2,
#   'Population': 81887.0,
#   'Population (20+)': 61893.0,
#   'Population (65+)': 12400.0,
#   'Staffed All Beds [Per 1000 People]': 0.855,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.131,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 5.645,
#   'Staffed ICU Beds [Per 1000 People]': 0.061,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.081,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.403,
#   'Licensed All Beds [Per 1000 People]': 1.575,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.084,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 10.403,
#   'fips': '01051'},
#  {'Staffed All Beds': 28.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 39.0,
#   'All Bed Occupancy Rate': 0.25,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 14726.0,
#   'Population (20+)': 10972.0,
#   'Population (65+)': 2829.0,
#   'Staffed All Beds [Per 1000 People]': 1.901,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.552,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 9.897,
#   'Staffed ICU Beds [Per 1000 People]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Licensed All Beds [Per 1000 People]': 2.648,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.555,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 13.786,
#   'fips': '01065'},
#  {'Staffed All Beds': 43.0,
#   'Staffed ICU Beds': 6.0,
#   'Licensed All Beds': 98.0,
#   'All Bed Occupancy Rate': 0.16,
#   'ICU Bed Occupancy Rate': 0.02,
#   'Population': 32957.0,
#   'Population (20+)': 25172.0,
#   'Population (65+)': 6151.0,
#   'Staffed All Beds [Per 1000 People]': 1.305,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.708,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 6.991,
#   'Staffed ICU Beds [Per 1000 People]': 0.182,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.238,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.975,
#   'Licensed All Beds [Per 1000 People]': 2.974,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.893,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 15.932,
#   'fips': '01079'},
#  {'Staffed All Beds': 97.0,
#   'Staffed ICU Beds': 10.0,
#   'Licensed All Beds': 102.0,
#   'All Bed Occupancy Rate': 0.52,
#   'ICU Bed Occupancy Rate': 0.23,
#   'Population': 96174.0,
#   'Population (20+)': 72418.0,
#   'Population (65+)': 14608.0,
#   'Staffed All Beds [Per 1000 People]': 1.009,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.339,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 6.64,
#   'Staffed ICU Beds [Per 1000 People]': 0.104,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.138,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.685,
#   'Licensed All Beds [Per 1000 People]': 1.061,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 1.408,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 6.982,
#   'fips': '01083'},
#  {'Staffed All Beds': 49.0,
#   'Staffed ICU Beds': 8.0,
#   'Licensed All Beds': 94.0,
#   'All Bed Occupancy Rate': 0.2,
#   'ICU Bed Occupancy Rate': 0.34,
#   'Population': 21067.0,
#   'Population (20+)': 15993.0,
#   'Population (65+)': 4275.0,
#   'Staffed All Beds [Per 1000 People]': 2.326,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.064,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 11.462,
#   'Staffed ICU Beds [Per 1000 People]': 0.38,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.5,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 1.871,
#   'Licensed All Beds [Per 1000 People]': 4.462,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.878,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 21.988,
#   'fips': '01099'},
#  {'Staffed All Beds': 40.0,
#   'Staffed ICU Beds': 4.0,
#   'Licensed All Beds': 56.0,
#   'All Bed Occupancy Rate': 0.15,
#   'ICU Bed Occupancy Rate': 0.0,
#   'Population': 19938.0,
#   'Population (20+)': 15570.0,
#   'Population (65+)': 3793.0,
#   'Staffed All Beds [Per 1000 People]': 2.006,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.569,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 10.546,
#   'Staffed ICU Beds [Per 1000 People]': 0.201,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.257,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 1.055,
#   'Licensed All Beds [Per 1000 People]': 2.809,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.597,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 14.764,
#   'fips': '01107'},
#  {'Staffed All Beds': 207.0,
#   'Staffed ICU Beds': 14.0,
#   'Licensed All Beds': 290.0,
#   'All Bed Occupancy Rate': 0.26,
#   'ICU Bed Occupancy Rate': 0.6,
#   'Population': 79828.0,
#   'Population (20+)': 61023.0,
#   'Population (65+)': 14370.0,
#   'Staffed All Beds [Per 1000 People]': 2.593,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.392,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 14.405,
#   'Staffed ICU Beds [Per 1000 People]': 0.175,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.229,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.974,
#   'Licensed All Beds [Per 1000 People]': 3.633,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.752,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 20.181,
#   'fips': '01121'},
#  {'Staffed All Beds': 25.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 25.0,
#   'All Bed Occupancy Rate': 0.23,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 12841.0,
#   'Population (20+)': 10028.0,
#   'Population (65+)': 2953.0,
#   'Staffed All Beds [Per 1000 People]': 1.947,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.493,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 8.466,
#   'Staffed ICU Beds [Per 1000 People]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Licensed All Beds [Per 1000 People]': 1.947,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.493,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 8.466,
#   'fips': '01023'},
#  {'Staffed All Beds': 56.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 85.0,
#   'All Bed Occupancy Rate': 0.3,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 23920.0,
#   'Population (20+)': 18171.0,
#   'Population (65+)': 4753.0,
#   'Staffed All Beds [Per 1000 People]': 2.341,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.082,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 11.782,
#   'Staffed ICU Beds [Per 1000 People]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Licensed All Beds [Per 1000 People]': 3.554,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.678,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 17.883,
#   'fips': '01025'},
#  {'Staffed All Beds': 99.0,
#   'Staffed ICU Beds': 7.0,
#   'Licensed All Beds': 131.0,
#   'All Bed Occupancy Rate': 0.28,
#   'ICU Bed Occupancy Rate': 0.34,
#   'Population': 51909.0,
#   'Population (20+)': 38476.0,
#   'Population (65+)': 8801.0,
#   'Staffed All Beds [Per 1000 People]': 1.907,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.573,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 11.249,
#   'Staffed ICU Beds [Per 1000 People]': 0.135,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.182,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.795,
#   'Licensed All Beds [Per 1000 People]': 2.524,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.405,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 14.885,
#   'fips': '01031'},
#  {'Staffed All Beds': 109.0,
#   'Staffed ICU Beds': 23.0,
#   'Licensed All Beds': 175.0,
#   'All Bed Occupancy Rate': 0.43,
#   'ICU Bed Occupancy Rate': 0.7,
#   'Population': 38310.0,
#   'Population (20+)': 28198.0,
#   'Population (65+)': 6921.0,
#   'Staffed All Beds [Per 1000 People]': 2.845,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.866,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 15.749,
#   'Staffed ICU Beds [Per 1000 People]': 0.6,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.816,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 3.323,
#   'Licensed All Beds [Per 1000 People]': 4.568,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 6.206,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 25.285,
#   'fips': '01047'},
#  {'Staffed All Beds': 590.0,
#   'Staffed ICU Beds': 56.0,
#   'Licensed All Beds': 739.0,
#   'All Bed Occupancy Rate': 0.5,
#   'ICU Bed Occupancy Rate': 0.86,
#   'Population': 102501.0,
#   'Population (20+)': 78222.0,
#   'Population (65+)': 19487.0,
#   'Staffed All Beds [Per 1000 People]': 5.756,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 7.543,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 30.277,
#   'Staffed ICU Beds [Per 1000 People]': 0.546,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.716,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 2.874,
#   'Licensed All Beds [Per 1000 People]': 7.21,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 9.447,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 37.923,
#   'fips': '01055'},
#  {'Staffed All Beds': 74.0,
#   'Staffed ICU Beds': 7.0,
#   'Licensed All Beds': 125.0,
#   'All Bed Occupancy Rate': 0.36,
#   'ICU Bed Occupancy Rate': 0.48,
#   'Population': 31363.0,
#   'Population (20+)': 22966.0,
#   'Population (65+)': 5296.0,
#   'Staffed All Beds [Per 1000 People]': 2.359,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.222,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 13.973,
#   'Staffed ICU Beds [Per 1000 People]': 0.223,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.305,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 1.322,
#   'Licensed All Beds [Per 1000 People]': 3.986,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.443,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 23.603,
#   'fips': '01059'},
#  {'Staffed All Beds': 73.0,
#   'Staffed ICU Beds': 6.0,
#   'Licensed All Beds': 83.0,
#   'All Bed Occupancy Rate': 0.16,
#   'ICU Bed Occupancy Rate': 0.22,
#   'Population': 26314.0,
#   'Population (20+)': 19997.0,
#   'Population (65+)': 5341.0,
#   'Staffed All Beds [Per 1000 People]': 2.774,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.651,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 13.668,
#   'Staffed ICU Beds [Per 1000 People]': 0.228,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.3,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 1.123,
#   'Licensed All Beds [Per 1000 People]': 3.154,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.151,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 15.54,
#   'fips': '01061'},
#  {'Staffed All Beds': 168.0,
#   'Staffed ICU Beds': 10.0,
#   'Licensed All Beds': 170.0,
#   'All Bed Occupancy Rate': 0.16,
#   'ICU Bed Occupancy Rate': 0.55,
#   'Population': 51736.0,
#   'Population (20+)': 39846.0,
#   'Population (65+)': 10373.0,
#   'Staffed All Beds [Per 1000 People]': 3.247,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.216,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 16.196,
#   'Staffed ICU Beds [Per 1000 People]': 0.193,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.251,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.964,
#   'Licensed All Beds [Per 1000 People]': 3.286,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.266,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 16.389,
#   'fips': '01071'},
#  {'Staffed All Beds': 477.0,
#   'Staffed ICU Beds': 36.0,
#   'Licensed All Beds': 500.0,
#   'All Bed Occupancy Rate': 0.59,
#   'ICU Bed Occupancy Rate': 0.47,
#   'Population': 163941.0,
#   'Population (20+)': 121363.0,
#   'Population (65+)': 19481.0,
#   'Staffed All Beds [Per 1000 People]': 2.91,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.93,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 24.485,
#   'Staffed ICU Beds [Per 1000 People]': 0.22,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.297,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 1.848,
#   'Licensed All Beds [Per 1000 People]': 3.05,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.12,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 25.666,
#   'fips': '01081'},
#  {'Staffed All Beds': 143.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 143.0,
#   'All Bed Occupancy Rate': None,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 18439.0,
#   'Population (20+)': 14238.0,
#   'Population (65+)': 3756.0,
#   'Staffed All Beds [Per 1000 People]': 7.755,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 10.044,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 38.072,
#   'Staffed ICU Beds [Per 1000 People]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Licensed All Beds [Per 1000 People]': 7.755,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 10.044,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 38.072,
#   'fips': '01087'},
#  {'Staffed All Beds': 1240.0,
#   'Staffed ICU Beds': 103.0,
#   'Licensed All Beds': 1244.0,
#   'All Bed Occupancy Rate': 0.73,
#   'ICU Bed Occupancy Rate': 0.79,
#   'Population': 366519.0,
#   'Population (20+)': 276519.0,
#   'Population (65+)': 55125.0,
#   'Staffed All Beds [Per 1000 People]': 3.383,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.484,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 22.494,
#   'Staffed ICU Beds [Per 1000 People]': 0.281,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.372,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 1.868,
#   'Licensed All Beds [Per 1000 People]': 3.394,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.499,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 22.567,
#   'fips': '01089'},
#  {'Staffed All Beds': 97.0,
#   'Staffed ICU Beds': 8.0,
#   'Licensed All Beds': 120.0,
#   'All Bed Occupancy Rate': 0.2,
#   'ICU Bed Occupancy Rate': 0.0,
#   'Population': 29763.0,
#   'Population (20+)': 22949.0,
#   'Population (65+)': 6321.0,
#   'Staffed All Beds [Per 1000 People]': 3.259,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.227,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 15.346,
#   'Staffed ICU Beds [Per 1000 People]': 0.269,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.349,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 1.266,
#   'Licensed All Beds [Per 1000 People]': 4.032,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.229,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 18.984,
#   'fips': '01093'},
#  {'Staffed All Beds': 204.0,
#   'Staffed ICU Beds': 20.0,
#   'Licensed All Beds': 294.0,
#   'All Bed Occupancy Rate': 0.51,
#   'ICU Bed Occupancy Rate': 0.72,
#   'Population': 96109.0,
#   'Population (20+)': 69982.0,
#   'Population (65+)': 16375.0,
#   'Staffed All Beds [Per 1000 People]': 2.123,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.915,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 12.458,
#   'Staffed ICU Beds [Per 1000 People]': 0.208,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.286,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 1.221,
#   'Licensed All Beds [Per 1000 People]': 3.059,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.201,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 17.954,
#   'fips': '01095'},
#  {'Staffed All Beds': 1639.0,
#   'Staffed ICU Beds': 157.0,
#   'Licensed All Beds': 2028.0,
#   'All Bed Occupancy Rate': 0.69,
#   'ICU Bed Occupancy Rate': 0.82,
#   'Population': 413757.0,
#   'Population (20+)': 306789.0,
#   'Population (65+)': 67041.0,
#   'Staffed All Beds [Per 1000 People]': 3.961,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 5.342,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 24.448,
#   'Staffed ICU Beds [Per 1000 People]': 0.379,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.512,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 2.342,
#   'Licensed All Beds [Per 1000 People]': 4.901,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 6.61,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 30.25,
#   'fips': '01097'},
#  {'Staffed All Beds': 1075.0,
#   'Staffed ICU Beds': 90.0,
#   'Licensed All Beds': 1321.0,
#   'All Bed Occupancy Rate': 0.71,
#   'ICU Bed Occupancy Rate': 0.7,
#   'Population': 225763.0,
#   'Population (20+)': 166708.0,
#   'Population (65+)': 34173.0,
#   'Staffed All Beds [Per 1000 People]': 4.762,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 6.448,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 31.458,
#   'Staffed ICU Beds [Per 1000 People]': 0.399,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.54,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 2.634,
#   'Licensed All Beds [Per 1000 People]': 5.851,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 7.924,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 38.656,
#   'fips': '01101'},
#  {'Staffed All Beds': 212.0,
#   'Staffed ICU Beds': 32.0,
#   'Licensed All Beds': 349.0,
#   'All Bed Occupancy Rate': 0.59,
#   'ICU Bed Occupancy Rate': 0.67,
#   'Population': 215707.0,
#   'Population (20+)': 159921.0,
#   'Population (65+)': 33087.0,
#   'Staffed All Beds [Per 1000 People]': 0.983,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.326,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 6.407,
#   'Staffed ICU Beds [Per 1000 People]': 0.148,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.2,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.967,
#   'Licensed All Beds [Per 1000 People]': 1.618,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.182,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 10.548,
#   'fips': '01117'},
#  {'Staffed All Beds': 33.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 33.0,
#   'All Bed Occupancy Rate': 0.45,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 12691.0,
#   'Population (20+)': 9629.0,
#   'Population (65+)': 2286.0,
#   'Staffed All Beds [Per 1000 People]': 2.6,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.427,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 14.436,
#   'Staffed ICU Beds [Per 1000 People]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Licensed All Beds [Per 1000 People]': 2.6,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.427,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 14.436,
#   'fips': '01119'},
#  {'Staffed All Beds': 553.0,
#   'Staffed ICU Beds': 84.0,
#   'Licensed All Beds': 843.0,
#   'All Bed Occupancy Rate': 0.78,
#   'ICU Bed Occupancy Rate': 0.95,
#   'Population': 208911.0,
#   'Population (20+)': 154939.0,
#   'Population (65+)': 27743.0,
#   'Staffed All Beds [Per 1000 People]': 2.647,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.569,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 19.933,
#   'Staffed ICU Beds [Per 1000 People]': 0.402,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.542,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 3.028,
#   'Licensed All Beds [Per 1000 People]': 4.035,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.441,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 30.386,
#   'fips': '01125'},
#  {'Staffed All Beds': 21.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 30.0,
#   'All Bed Occupancy Rate': 0.07,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 10627.0,
#   'Population (20+)': 7803.0,
#   'Population (65+)': 2066.0,
#   'Staffed All Beds [Per 1000 People]': 1.976,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.691,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 10.165,
#   'Staffed ICU Beds [Per 1000 People]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Licensed All Beds [Per 1000 People]': 2.823,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.845,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 14.521,
#   'fips': '01131'},
#  {'Staffed All Beds': 25.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 35.0,
#   'All Bed Occupancy Rate': 0.37,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 22400.0,
#   'Population (20+)': 17348.0,
#   'Population (65+)': 3690.0,
#   'Staffed All Beds [Per 1000 People]': 1.116,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.441,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 6.775,
#   'Staffed ICU Beds [Per 1000 People]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Licensed All Beds [Per 1000 People]': 1.562,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.018,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 9.485,
#   'fips': '01007'},
#  {'Staffed All Beds': 30.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 61.0,
#   'All Bed Occupancy Rate': 0.21,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 10138.0,
#   'Population (20+)': 7810.0,
#   'Population (65+)': 1661.0,
#   'Staffed All Beds [Per 1000 People]': 2.959,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.841,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 18.061,
#   'Staffed ICU Beds [Per 1000 People]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Licensed All Beds [Per 1000 People]': 6.017,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 7.81,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 36.725,
#   'fips': '01011'},
#  {'Staffed All Beds': 446.0,
#   'Staffed ICU Beds': 24.0,
#   'Licensed All Beds': 590.0,
#   'All Bed Occupancy Rate': 0.49,
#   'ICU Bed Occupancy Rate': 0.94,
#   'Population': 114277.0,
#   'Population (20+)': 86499.0,
#   'Population (65+)': 20247.0,
#   'Staffed All Beds [Per 1000 People]': 3.903,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 5.156,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 22.028,
#   'Staffed ICU Beds [Per 1000 People]': 0.21,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.277,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 1.185,
#   'Licensed All Beds [Per 1000 People]': 5.163,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 6.821,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 29.14,
#   'fips': '01015'},
#  {'Staffed All Beds': 362.0,
#   'Staffed ICU Beds': 51.0,
#   'Licensed All Beds': 386.0,
#   'All Bed Occupancy Rate': 0.64,
#   'ICU Bed Occupancy Rate': 0.65,
#   'Population': 218022.0,
#   'Population (20+)': 166352.0,
#   'Population (65+)': 44571.0,
#   'Staffed All Beds [Per 1000 People]': 1.66,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.176,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 8.122,
#   'Staffed ICU Beds [Per 1000 People]': 0.234,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.307,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 1.144,
#   'Licensed All Beds [Per 1000 People]': 1.77,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.32,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 8.66,
#   'fips': '01003'},
#  {'Staffed All Beds': 46.0,
#   'Staffed ICU Beds': 4.0,
#   'Licensed All Beds': 46.0,
#   'All Bed Occupancy Rate': 0.29,
#   'ICU Bed Occupancy Rate': 0.41,
#   'Population': 13275.0,
#   'Population (20+)': 10291.0,
#   'Population (65+)': 2751.0,
#   'Staffed All Beds [Per 1000 People]': 3.465,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.47,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 16.721,
#   'Staffed ICU Beds [Per 1000 People]': 0.301,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.389,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 1.454,
#   'Licensed All Beds [Per 1000 People]': 3.465,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.47,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 16.721,
#   'fips': '01027'},
#  {'Staffed All Beds': 29.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 93.0,
#   'All Bed Occupancy Rate': 0.12,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 13824.0,
#   'Population (20+)': 10378.0,
#   'Population (65+)': 2629.0,
#   'Staffed All Beds [Per 1000 People]': 2.098,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.794,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 11.031,
#   'Staffed ICU Beds [Per 1000 People]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Licensed All Beds [Per 1000 People]': 6.727,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 8.961,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 35.375,
#   'fips': '01041'},
#  {'Staffed All Beds': 45.0,
#   'Staffed ICU Beds': 8.0,
#   'Licensed All Beds': 61.0,
#   'All Bed Occupancy Rate': 0.26,
#   'ICU Bed Occupancy Rate': 0.04,
#   'Population': 16433.0,
#   'Population (20+)': 12612.0,
#   'Population (65+)': 3472.0,
#   'Staffed All Beds [Per 1000 People]': 2.738,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.568,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 12.961,
#   'Staffed ICU Beds [Per 1000 People]': 0.487,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.634,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 2.304,
#   'Licensed All Beds [Per 1000 People]': 3.712,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.837,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 17.569,
#   'fips': '01057'},
#  {'Staffed All Beds': 3696.0,
#   'Staffed ICU Beds': 477.0,
#   'Licensed All Beds': 4732.0,
#   'All Bed Occupancy Rate': 0.72,
#   'ICU Bed Occupancy Rate': 0.75,
#   'Population': 659300.0,
#   'Population (20+)': 492611.0,
#   'Population (65+)': 104547.0,
#   'Staffed All Beds [Per 1000 People]': 5.606,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 7.503,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 35.353,
#   'Staffed ICU Beds [Per 1000 People]': 0.723,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.968,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 4.563,
#   'Licensed All Beds [Per 1000 People]': 7.177,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 9.606,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 45.262,
#   'fips': '01073'},
#  {'Staffed All Beds': 37.0,
#   'Staffed ICU Beds': 5.0,
#   'Licensed All Beds': 99.0,
#   'All Bed Occupancy Rate': 0.44,
#   'ICU Bed Occupancy Rate': 0.51,
#   'Population': 19066.0,
#   'Population (20+)': 14322.0,
#   'Population (65+)': 3737.0,
#   'Staffed All Beds [Per 1000 People]': 1.941,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.583,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 9.901,
#   'Staffed ICU Beds [Per 1000 People]': 0.262,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.349,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 1.338,
#   'Licensed All Beds [Per 1000 People]': 5.192,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 6.912,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 26.492,
#   'fips': '01091'},
#  {'Staffed All Beds': 200.0,
#   'Staffed ICU Beds': 34.0,
#   'Licensed All Beds': 445.0,
#   'All Bed Occupancy Rate': 0.56,
#   'ICU Bed Occupancy Rate': 0.72,
#   'Population': 119089.0,
#   'Population (20+)': 89280.0,
#   'Population (65+)': 20803.0,
#   'Staffed All Beds [Per 1000 People]': 1.679,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.24,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 9.614,
#   'Staffed ICU Beds [Per 1000 People]': 0.286,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.381,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 1.634,
#   'Licensed All Beds [Per 1000 People]': 3.737,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.984,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 21.391,
#   'fips': '01103'},
#  {'Staffed All Beds': 40.0,
#   'Staffed ICU Beds': 6.0,
#   'Licensed All Beds': 40.0,
#   'All Bed Occupancy Rate': 0.58,
#   'ICU Bed Occupancy Rate': 0.64,
#   'Population': 88690.0,
#   'Population (20+)': 66809.0,
#   'Population (65+)': 14738.0,
#   'Staffed All Beds [Per 1000 People]': 0.451,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 0.599,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 2.714,
#   'Staffed ICU Beds [Per 1000 People]': 0.068,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.09,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.407,
#   'Licensed All Beds [Per 1000 People]': 0.451,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 0.599,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 2.714,
#   'fips': '01115'},
#  {'Staffed All Beds': 15.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 25.0,
#   'All Bed Occupancy Rate': 0.39,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 16378.0,
#   'Population (20+)': 12385.0,
#   'Population (65+)': 3130.0,
#   'Staffed All Beds [Per 1000 People]': 0.916,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.211,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 4.792,
#   'Staffed ICU Beds [Per 1000 People]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Licensed All Beds [Per 1000 People]': 1.526,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.019,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 7.987,
#   'fips': '01129'},
#  {'Staffed All Beds': 30.0,
#   'Staffed ICU Beds': 5.0,
#   'Licensed All Beds': 74.0,
#   'All Bed Occupancy Rate': 0.43,
#   'ICU Bed Occupancy Rate': 0.42,
#   'Population': 24881.0,
#   'Population (20+)': 19189.0,
#   'Population (65+)': 4832.0,
#   'Staffed All Beds [Per 1000 People]': 1.206,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.563,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 6.209,
#   'Staffed ICU Beds [Per 1000 People]': 0.201,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.261,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 1.035,
#   'Licensed All Beds [Per 1000 People]': 2.974,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.856,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 15.315,
#   'fips': '01005'},
#  {'Staffed All Beds': 66.0,
#   'Staffed ICU Beds': 7.0,
#   'Licensed All Beds': 94.0,
#   'All Bed Occupancy Rate': 0.18,
#   'ICU Bed Occupancy Rate': 0.38,
#   'Population': 19680.0,
#   'Population (20+)': 14868.0,
#   'Population (65+)': 3995.0,
#   'Staffed All Beds [Per 1000 People]': 3.354,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.439,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 16.521,
#   'Staffed ICU Beds [Per 1000 People]': 0.356,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.471,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 1.752,
#   'Licensed All Beds [Per 1000 People]': 4.776,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 6.322,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 23.529,
#   'fips': '01013'},
#  {'Staffed All Beds': 45.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 60.0,
#   'All Bed Occupancy Rate': 0.24,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 26032.0,
#   'Population (20+)': 20497.0,
#   'Population (65+)': 5980.0,
#   'Staffed All Beds [Per 1000 People]': 1.729,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.195,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 7.525,
#   'Staffed ICU Beds [Per 1000 People]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Licensed All Beds [Per 1000 People]': 2.305,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.927,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 10.033,
#   'fips': '01019'},
#  {'Staffed All Beds': 44.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 58.0,
#   'All Bed Occupancy Rate': 0.29,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 12277.0,
#   'Population (20+)': 9476.0,
#   'Population (65+)': 2762.0,
#   'Staffed All Beds [Per 1000 People]': 3.584,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.643,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 15.93,
#   'Staffed ICU Beds [Per 1000 People]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Licensed All Beds [Per 1000 People]': 4.724,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 6.121,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 20.999,
#   'fips': '01035'},
#  {'Staffed All Beds': 128.0,
#   'Staffed ICU Beds': 13.0,
#   'Licensed All Beds': 187.0,
#   'All Bed Occupancy Rate': 0.32,
#   'ICU Bed Occupancy Rate': 0.68,
#   'Population': 36986.0,
#   'Population (20+)': 28151.0,
#   'Population (65+)': 7790.0,
#   'Staffed All Beds [Per 1000 People]': 3.461,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.547,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 16.431,
#   'Staffed ICU Beds [Per 1000 People]': 0.351,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.462,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 1.669,
#   'Licensed All Beds [Per 1000 People]': 5.056,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 6.643,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 24.005,
#   'fips': '01039'},
#  {'Staffed All Beds': 97.0,
#   'Staffed ICU Beds': 12.0,
#   'Licensed All Beds': 134.0,
#   'All Bed Occupancy Rate': 0.32,
#   'ICU Bed Occupancy Rate': 0.46,
#   'Population': 71385.0,
#   'Population (20+)': 52447.0,
#   'Population (65+)': 12322.0,
#   'Staffed All Beds [Per 1000 People]': 1.359,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.849,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 7.872,
#   'Staffed ICU Beds [Per 1000 People]': 0.168,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.229,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.974,
#   'Licensed All Beds [Per 1000 People]': 1.877,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.555,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 10.875,
#   'fips': '01049'},
#  {'Staffed All Beds': 95.0,
#   'Staffed ICU Beds': 14.0,
#   'Licensed All Beds': 142.0,
#   'All Bed Occupancy Rate': 0.34,
#   'ICU Bed Occupancy Rate': 0.39,
#   'Population': 36748.0,
#   'Population (20+)': 27795.0,
#   'Population (65+)': 6596.0,
#   'Staffed All Beds [Per 1000 People]': 2.585,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.418,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 14.403,
#   'Staffed ICU Beds [Per 1000 People]': 0.381,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.504,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 2.122,
#   'Licensed All Beds [Per 1000 People]': 3.864,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.109,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 21.528,
#   'fips': '01053'},
#  {'Staffed All Beds': 20.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 20.0,
#   'All Bed Occupancy Rate': 0.06,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 8233.0,
#   'Population (20+)': 6242.0,
#   'Population (65+)': 1837.0,
#   'Staffed All Beds [Per 1000 People]': 2.429,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.204,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 10.887,
#   'Staffed ICU Beds [Per 1000 People]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Licensed All Beds [Per 1000 People]': 2.429,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.204,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 10.887,
#   'fips': '01063'},
#  {'Staffed All Beds': 651.0,
#   'Staffed ICU Beds': 66.0,
#   'Licensed All Beds': 790.0,
#   'All Bed Occupancy Rate': 0.74,
#   'ICU Bed Occupancy Rate': 0.86,
#   'Population': 104722.0,
#   'Population (20+)': 78351.0,
#   'Population (65+)': 18639.0,
#   'Staffed All Beds [Per 1000 People]': 6.216,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 8.309,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 34.927,
#   'Staffed ICU Beds [Per 1000 People]': 0.63,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.842,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 3.541,
#   'Licensed All Beds [Per 1000 People]': 7.544,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 10.083,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 42.384,
#   'fips': '01069'},
#  {'Staffed All Beds': 233.0,
#   'Staffed ICU Beds': 52.0,
#   'Licensed All Beds': 263.0,
#   'All Bed Occupancy Rate': 0.73,
#   'ICU Bed Occupancy Rate': 0.43,
#   'Population': 92387.0,
#   'Population (20+)': 71476.0,
#   'Population (65+)': 18563.0,
#   'Staffed All Beds [Per 1000 People]': 2.522,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.26,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 12.552,
#   'Staffed ICU Beds [Per 1000 People]': 0.563,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.728,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 2.801,
#   'Licensed All Beds [Per 1000 People]': 2.847,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.68,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 14.168,
#   'fips': '01077'},
#  {'Staffed All Beds': 0.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 34.0,
#   'All Bed Occupancy Rate': None,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 22725.0,
#   'Population (20+)': 17231.0,
#   'Population (65+)': 4625.0,
#   'Staffed All Beds [Per 1000 People]': 0.0,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 People]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Licensed All Beds [Per 1000 People]': 1.496,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 1.973,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 7.351,
#   'fips': '01111'},
#  {'Staffed All Beds': 80.0,
#   'Staffed ICU Beds': 6.0,
#   'Licensed All Beds': 127.0,
#   'All Bed Occupancy Rate': 0.33,
#   'ICU Bed Occupancy Rate': 0.83,
#   'Population': 40497.0,
#   'Population (20+)': 31297.0,
#   'Population (65+)': 8731.0,
#   'Staffed All Beds [Per 1000 People]': 1.975,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.556,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 9.163,
#   'Staffed ICU Beds [Per 1000 People]': 0.148,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.192,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.687,
#   'Licensed All Beds [Per 1000 People]': 3.136,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.058,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 14.546,
#   'fips': '01123'},
#  {'Staffed All Beds': 207.0,
#   'Staffed ICU Beds': 12.0,
#   'Licensed All Beds': 267.0,
#   'All Bed Occupancy Rate': 0.31,
#   'ICU Bed Occupancy Rate': 0.67,
#   'Population': 63711.0,
#   'Population (20+)': 48270.0,
#   'Population (65+)': 12311.0,
#   'Staffed All Beds [Per 1000 People]': 3.249,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.288,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 16.814,
#   'Staffed ICU Beds [Per 1000 People]': 0.188,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.249,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.975,
#   'Licensed All Beds [Per 1000 People]': 4.191,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.531,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 21.688,
#   'fips': '01127'},
#  {'Staffed All Beds': 49.0,
#   'Staffed ICU Beds': 4.0,
#   'Licensed All Beds': 49.0,
#   'All Bed Occupancy Rate': 0.28,
#   'ICU Bed Occupancy Rate': 0.04,
#   'Population': 23660.0,
#   'Population (20+)': 18335.0,
#   'Population (65+)': 5101.0,
#   'Staffed All Beds [Per 1000 People]': 2.071,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.672,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 9.606,
#   'Staffed ICU Beds [Per 1000 People]': 0.169,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.218,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.784,
#   'Licensed All Beds [Per 1000 People]': 2.071,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.672,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 9.606,
#   'fips': '01133'},
#  {'Staffed All Beds': 185.0,
#   'Staffed ICU Beds': 12.0,
#   'Licensed All Beds': 185.0,
#   'All Bed Occupancy Rate': 0.49,
#   'ICU Bed Occupancy Rate': 0.69,
#   'Population': 83442.0,
#   'Population (20+)': 62910.0,
#   'Population (65+)': 15446.0,
#   'Staffed All Beds [Per 1000 People]': 2.217,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.941,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 11.977,
#   'Staffed ICU Beds [Per 1000 People]': 0.144,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.191,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.777,
#   'Licensed All Beds [Per 1000 People]': 2.217,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.941,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 11.977,
#   'fips': '01043'},
#  {'Staffed All Beds': 97.0,
#   'Staffed ICU Beds': 9.0,
#   'Licensed All Beds': 97.0,
#   'All Bed Occupancy Rate': 0.18,
#   'ICU Bed Occupancy Rate': 0.3,
#   'Population': 33338.0,
#   'Population (20+)': 25104.0,
#   'Population (65+)': 4987.0,
#   'Staffed All Beds [Per 1000 People]': 2.91,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.864,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 19.451,
#   'Staffed ICU Beds [Per 1000 People]': 0.27,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.359,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 1.805,
#   'Licensed All Beds [Per 1000 People]': 2.91,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.864,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 19.451,
#   'fips': '01109'},
#  {'Staffed All Beds': 34.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 37.0,
#   'All Bed Occupancy Rate': 0.4,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 18216.0,
#   'Population (20+)': 11082.0,
#   'Population (65+)': 1402.0,
#   'Staffed All Beds [Per 1000 People]': 1.866,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.068,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 24.251,
#   'Staffed ICU Beds [Per 1000 People]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Licensed All Beds [Per 1000 People]': 2.031,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.339,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 26.391,
#   'fips': '02050'},
#  {'Staffed All Beds': 76.0,
#   'Staffed ICU Beds': 6.0,
#   'Licensed All Beds': 77.0,
#   'All Bed Occupancy Rate': 0.56,
#   'ICU Bed Occupancy Rate': 0.69,
#   'Population': 58533.0,
#   'Population (20+)': 44086.0,
#   'Population (65+)': 10188.0,
#   'Staffed All Beds [Per 1000 People]': 1.298,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.724,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 7.46,
#   'Staffed ICU Beds [Per 1000 People]': 0.103,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.136,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.589,
#   'Licensed All Beds [Per 1000 People]': 1.315,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 1.747,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 7.558,
#   'fips': '02122'},
#  {'Staffed All Beds': 24.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 25.0,
#   'All Bed Occupancy Rate': 0.22,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 13345.0,
#   'Population (20+)': 9602.0,
#   'Population (65+)': 1379.0,
#   'Staffed All Beds [Per 1000 People]': 1.798,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.499,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 17.404,
#   'Staffed ICU Beds [Per 1000 People]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Licensed All Beds [Per 1000 People]': 1.873,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.604,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 18.129,
#   'fips': '02150'},
#  {'Staffed All Beds': 0.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 36.0,
#   'All Bed Occupancy Rate': None,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 10008.0,
#   'Population (20+)': 6248.0,
#   'Population (65+)': 774.0,
#   'Staffed All Beds [Per 1000 People]': 0.0,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 People]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Licensed All Beds [Per 1000 People]': 3.597,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.762,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 46.512,
#   'fips': '02180'},
#  {'Staffed All Beds': 17.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 17.0,
#   'All Bed Occupancy Rate': 0.23,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 7671.0,
#   'Population (20+)': 4736.0,
#   'Population (65+)': 561.0,
#   'Staffed All Beds [Per 1000 People]': 2.216,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.59,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 30.303,
#   'Staffed ICU Beds [Per 1000 People]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Licensed All Beds [Per 1000 People]': 2.216,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.59,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 30.303,
#   'fips': '02188'},
#  {'Staffed All Beds': 24.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 24.0,
#   'All Bed Occupancy Rate': 0.22,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 9164.0,
#   'Population (20+)': 6823.0,
#   'Population (65+)': 1256.0,
#   'Staffed All Beds [Per 1000 People]': 2.619,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.518,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 19.108,
#   'Staffed ICU Beds [Per 1000 People]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Licensed All Beds [Per 1000 People]': 2.619,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.518,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 19.108,
#   'fips': '02261'},
#  {'Staffed All Beds': 18.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 18.0,
#   'All Bed Occupancy Rate': 0.15,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 5000.0,
#   'Population (20+)': 3278.0,
#   'Population (65+)': 470.0,
# ...
#   'Licensed All Beds [Per 1000 Adults (20+)]': 10.36,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 30.211,
#   'fips': '27011'},
#  {'Staffed All Beds': 47.0,
#   'Staffed ICU Beds': 6.0,
#   'Licensed All Beds': 105.0,
#   'All Bed Occupancy Rate': 0.33,
#   'ICU Bed Occupancy Rate': 0.03,
#   'Population': 35837.0,
#   'Population (20+)': 27052.0,
#   'Population (65+)': 6136.0,
#   'Staffed All Beds [Per 1000 People]': 1.311,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.737,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 7.66,
#   'Staffed ICU Beds [Per 1000 People]': 0.167,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.222,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.978,
#   'Licensed All Beds [Per 1000 People]': 2.93,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.881,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 17.112,
#   'fips': '27017'},
#  {'Staffed All Beds': 55.0,
#   'Staffed ICU Beds': 10.0,
#   'Licensed All Beds': 61.0,
#   'All Bed Occupancy Rate': 0.51,
#   'ICU Bed Occupancy Rate': 0.51,
#   'Population': 55922.0,
#   'Population (20+)': 41970.0,
#   'Population (65+)': 8612.0,
#   'Staffed All Beds [Per 1000 People]': 0.984,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.31,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 6.386,
#   'Staffed ICU Beds [Per 1000 People]': 0.179,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.238,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 1.161,
#   'Licensed All Beds [Per 1000 People]': 1.091,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 1.453,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 7.083,
#   'fips': '27025'},
#  {'Staffed All Beds': 152.0,
#   'Staffed ICU Beds': 16.0,
#   'Licensed All Beds': 204.0,
#   'All Bed Occupancy Rate': 0.43,
#   'ICU Bed Occupancy Rate': 0.34,
#   'Population': 64889.0,
#   'Population (20+)': 49621.0,
#   'Population (65+)': 14549.0,
#   'Staffed All Beds [Per 1000 People]': 2.342,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.063,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 10.447,
#   'Staffed ICU Beds [Per 1000 People]': 0.247,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.322,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 1.1,
#   'Licensed All Beds [Per 1000 People]': 3.144,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.111,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 14.022,
#   'fips': '27035'},
#  {'Staffed All Beds': 237.0,
#   'Staffed ICU Beds': 16.0,
#   'Licensed All Beds': 265.0,
#   'All Bed Occupancy Rate': 0.65,
#   'ICU Bed Occupancy Rate': 0.84,
#   'Population': 425423.0,
#   'Population (20+)': 312519.0,
#   'Population (65+)': 60282.0,
#   'Staffed All Beds [Per 1000 People]': 0.557,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 0.758,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 3.932,
#   'Staffed ICU Beds [Per 1000 People]': 0.038,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.051,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.265,
#   'Licensed All Beds [Per 1000 People]': 0.623,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 0.848,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 4.396,
#   'fips': '27037'},
#  {'Staffed All Beds': 99.0,
#   'Staffed ICU Beds': 8.0,
#   'Licensed All Beds': 127.0,
#   'All Bed Occupancy Rate': 0.33,
#   'ICU Bed Occupancy Rate': 0.35,
#   'Population': 37964.0,
#   'Population (20+)': 29069.0,
#   'Population (65+)': 8651.0,
#   'Staffed All Beds [Per 1000 People]': 2.608,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.406,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 11.444,
#   'Staffed ICU Beds [Per 1000 People]': 0.211,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.275,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.925,
#   'Licensed All Beds [Per 1000 People]': 3.345,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.369,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 14.68,
#   'fips': '27041'},
#  {'Staffed All Beds': 24.0,
#   'Staffed ICU Beds': 4.0,
#   'Licensed All Beds': 43.0,
#   'All Bed Occupancy Rate': 0.37,
#   'ICU Bed Occupancy Rate': 0.01,
#   'Population': 13758.0,
#   'Population (20+)': 10437.0,
#   'Population (65+)': 3140.0,
#   'Staffed All Beds [Per 1000 People]': 1.744,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.3,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 7.643,
#   'Staffed ICU Beds [Per 1000 People]': 0.291,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.383,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 1.274,
#   'Licensed All Beds [Per 1000 People]': 3.125,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.12,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 13.694,
#   'fips': '27043'},
#  {'Staffed All Beds': 3373.0,
#   'Staffed ICU Beds': 378.0,
#   'Licensed All Beds': 5600.0,
#   'All Bed Occupancy Rate': 0.69,
#   'ICU Bed Occupancy Rate': 0.72,
#   'Population': 1259428.0,
#   'Population (20+)': 953873.0,
#   'Population (65+)': 176788.0,
#   'Staffed All Beds [Per 1000 People]': 2.678,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.536,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 19.079,
#   'Staffed ICU Beds [Per 1000 People]': 0.3,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.396,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 2.138,
#   'Licensed All Beds [Per 1000 People]': 4.446,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.871,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 31.676,
#   'fips': '27053'},
#  {'Staffed All Beds': 70.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 86.0,
#   'All Bed Occupancy Rate': 0.4,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 39966.0,
#   'Population (20+)': 29753.0,
#   'Population (65+)': 6424.0,
#   'Staffed All Beds [Per 1000 People]': 1.751,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.353,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 10.897,
#   'Staffed ICU Beds [Per 1000 People]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Licensed All Beds [Per 1000 People]': 2.152,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.89,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 13.387,
#   'fips': '27059'},
#  {'Staffed All Beds': 14.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 20.0,
#   'All Bed Occupancy Rate': 0.15,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 9911.0,
#   'Population (20+)': 7573.0,
#   'Population (65+)': 2217.0,
#   'Staffed All Beds [Per 1000 People]': 1.413,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.849,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 6.315,
#   'Staffed ICU Beds [Per 1000 People]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Licensed All Beds [Per 1000 People]': 2.018,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.641,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 9.021,
#   'fips': '27063'},
#  {'Staffed All Beds': 25.0,
#   'Staffed ICU Beds': 4.0,
#   'Licensed All Beds': 49.0,
#   'All Bed Occupancy Rate': 0.38,
#   'ICU Bed Occupancy Rate': 0.08,
#   'Population': 16207.0,
#   'Population (20+)': 12394.0,
#   'Population (65+)': 3324.0,
#   'Staffed All Beds [Per 1000 People]': 1.543,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.017,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 7.521,
#   'Staffed ICU Beds [Per 1000 People]': 0.247,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.323,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 1.203,
#   'Licensed All Beds [Per 1000 People]': 3.023,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.954,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 14.741,
#   'fips': '27065'},
#  {'Staffed All Beds': 15.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 15.0,
#   'All Bed Occupancy Rate': 0.1,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 4248.0,
#   'Population (20+)': 3245.0,
#   'Population (65+)': 1036.0,
#   'Staffed All Beds [Per 1000 People]': 3.531,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.622,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 14.479,
#   'Staffed ICU Beds [Per 1000 People]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Licensed All Beds [Per 1000 People]': 3.531,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.622,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 14.479,
#   'fips': '27069'},
#  {'Staffed All Beds': 18.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 25.0,
#   'All Bed Occupancy Rate': 0.34,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 12440.0,
#   'Population (20+)': 9876.0,
#   'Population (65+)': 3179.0,
#   'Staffed All Beds [Per 1000 People]': 1.447,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.823,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 5.662,
#   'Staffed ICU Beds [Per 1000 People]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Licensed All Beds [Per 1000 People]': 2.01,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.531,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 7.864,
#   'fips': '27071'},
#  {'Staffed All Beds': 9.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 15.0,
#   'All Bed Occupancy Rate': 0.2,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 28494.0,
#   'Population (20+)': 21105.0,
#   'Population (65+)': 4987.0,
#   'Staffed All Beds [Per 1000 People]': 0.316,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 0.426,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 1.805,
#   'Staffed ICU Beds [Per 1000 People]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Licensed All Beds [Per 1000 People]': 0.526,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 0.711,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 3.008,
#   'fips': '27079'},
#  {'Staffed All Beds': 10.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 18.0,
#   'All Bed Occupancy Rate': 0.14,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 5519.0,
#   'Population (20+)': 3639.0,
#   'Population (65+)': 951.0,
#   'Staffed All Beds [Per 1000 People]': 1.812,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.748,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 10.515,
#   'Staffed ICU Beds [Per 1000 People]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Licensed All Beds [Per 1000 People]': 3.261,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.946,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 18.927,
#   'fips': '27087'},
#  {'Staffed All Beds': 20.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 25.0,
#   'All Bed Occupancy Rate': 0.16,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 8276.0,
#   'Population (20+)': 6302.0,
#   'Population (65+)': 2111.0,
#   'Staffed All Beds [Per 1000 People]': 2.417,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.174,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 9.474,
#   'Staffed ICU Beds [Per 1000 People]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Licensed All Beds [Per 1000 People]': 3.021,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.967,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 11.843,
#   'fips': '27101'},
#  {'Staffed All Beds': 14.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 14.0,
#   'All Bed Occupancy Rate': 0.04,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 6475.0,
#   'Population (20+)': 4792.0,
#   'Population (65+)': 1366.0,
#   'Staffed All Beds [Per 1000 People]': 2.162,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.922,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 10.249,
#   'Staffed ICU Beds [Per 1000 People]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Licensed All Beds [Per 1000 People]': 2.162,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.922,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 10.249,
#   'fips': '27107'},
#  {'Staffed All Beds': 32.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 49.0,
#   'All Bed Occupancy Rate': 0.37,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 66523.0,
#   'Population (20+)': 48821.0,
#   'Population (65+)': 10250.0,
#   'Staffed All Beds [Per 1000 People]': 0.481,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 0.655,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 3.122,
#   'Staffed ICU Beds [Per 1000 People]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Licensed All Beds [Per 1000 People]': 0.737,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 1.004,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 4.78,
#   'fips': '27131'},
#  {'Staffed All Beds': 16.0,
#   'Staffed ICU Beds': 0.0,
#   'Licensed All Beds': 20.0,
#   'All Bed Occupancy Rate': 0.15,
#   'ICU Bed Occupancy Rate': None,
#   'Population': 15028.0,
#   'Population (20+)': 11148.0,
#   'Population (65+)': 2756.0,
#   'Staffed All Beds [Per 1000 People]': 1.065,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.435,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 5.806,
#   'Staffed ICU Beds [Per 1000 People]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.0,
#   'Licensed All Beds [Per 1000 People]': 1.331,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 1.794,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 7.257,
#   'fips': '27143'},
#  {'Staffed All Beds': 25.0,
#   'Staffed ICU Beds': 2.0,
#   'Licensed All Beds': 49.0,
#   'All Bed Occupancy Rate': 0.28,
#   'ICU Bed Occupancy Rate': 0.03,
#   'Population': 13773.0,
#   'Population (20+)': 9954.0,
#   'Population (65+)': 2897.0,
#   'Staffed All Beds [Per 1000 People]': 1.815,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.512,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 8.63,
#   'Staffed ICU Beds [Per 1000 People]': 0.145,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.201,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.69,
#   'Licensed All Beds [Per 1000 People]': 3.558,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.923,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 16.914,
#   'fips': '27159'},
#  {'Staffed All Beds': 41.0,
#   'Staffed ICU Beds': 8.0,
#   'Licensed All Beds': 49.0,
#   'All Bed Occupancy Rate': 0.45,
#   'ICU Bed Occupancy Rate': 0.25,
#   'Population': 50825.0,
#   'Population (20+)': 38657.0,
#   'Population (65+)': 8631.0,
#   'Staffed All Beds [Per 1000 People]': 0.807,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.061,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 4.75,
#   'Staffed ICU Beds [Per 1000 People]': 0.157,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.207,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 0.927,
#   'Licensed All Beds [Per 1000 People]': 0.964,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 1.268,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 5.677,
#   'fips': '27169'},
#  {'Staffed All Beds': 36.0,
#   'Staffed ICU Beds': 8.0,
#   'Licensed All Beds': 87.0,
#   'All Bed Occupancy Rate': 0.51,
#   'ICU Bed Occupancy Rate': 0.43,
#   'Population': 34371.0,
#   'Population (20+)': 25262.0,
#   'Population (65+)': 7052.0,
#   'Staffed All Beds [Per 1000 People]': 1.047,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.425,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 5.105,
#   'Staffed ICU Beds [Per 1000 People]': 0.233,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.317,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 1.134,
#   'Licensed All Beds [Per 1000 People]': 2.531,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.444,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 12.337,
#   'fips': '27005'},
#  {'Staffed All Beds': 167.0,
#   'Staffed ICU Beds': 29.0,
#   'Licensed All Beds': 272.0,
#   'All Bed Occupancy Rate': 0.68,
#   'ICU Bed Occupancy Rate': 0.51,
#   'Population': 67427.0,
#   'Population (20+)': 50559.0,
#   'Population (65+)': 9368.0,
#   'Staffed All Beds [Per 1000 People]': 2.477,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.303,
#   'Staffed All Beds [Per 1000 Elderly (65+)]': 17.827,
#   'Staffed ICU Beds [Per 1000 People]': 0.43,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.574,
#   'Staffed ICU Beds [Per 1000 Elderly (65+)]': 3.096,
#   'Licensed All Beds [Per 1000 People]': 4.034,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.38,
#   'Licensed All Beds [Per 1000 Elderly (65+)]': 29.035,
#   'fips': '27013'},
#  ...]

# %%
#combine both the hospital and risk data in one json file 
count = 0
for i in dataR:
    fips = i['fips']
    for j in dataH:
        if j['fips'] == fips:
            i["Staffed All Beds [Per 1000 Adults (20+)]"] = j["Staffed All Beds [Per 1000 Adults (20+)]"]
            i["Staffed ICU Beds [Per 1000 Adults (20+)]"] = j["Staffed ICU Beds [Per 1000 Adults (20+)]"]
            i["Licensed All Beds [Per 1000 Adults (20+)]"] = j["Licensed All Beds [Per 1000 Adults (20+)]"]

# %%
dataR
# Out:
# [{'fips': '02013',
#   'risk': 2,
#   'infectionRate': 1.03,
#   'county': 'Aleutians East Borough',
#   'vaccinationsInitiatedRatio': 0.851},
#  {'fips': '02016',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Aleutians West Census Area',
#   'vaccinationsInitiatedRatio': 0.746,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 0.0},
#  {'fips': '02020',
#   'risk': 3,
#   'infectionRate': 0.98,
#   'county': 'Anchorage Municipality',
#   'vaccinationsInitiatedRatio': 0.757,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.585,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.342,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.382},
#  {'fips': '02050',
#   'risk': 3,
#   'infectionRate': 0.71,
#   'county': 'Bethel Census Area',
#   'vaccinationsInitiatedRatio': 0.723,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.068,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.339},
#  {'fips': '02060',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'Bristol Bay Borough',
#   'vaccinationsInitiatedRatio': None},
#  {'fips': '02068',
#   'risk': 1,
#   'infectionRate': None,
#   'county': 'Denali Borough',
#   'vaccinationsInitiatedRatio': 0.629},
#  {'fips': '02070',
#   'risk': 5,
#   'infectionRate': 0.65,
#   'county': 'Dillingham Census Area',
#   'vaccinationsInitiatedRatio': 0.574,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 5.491,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.491},
#  {'fips': '02090',
#   'risk': 2,
#   'infectionRate': 0.89,
#   'county': 'Fairbanks North Star Borough',
#   'vaccinationsInitiatedRatio': 0.68,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.179,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.414},
#  {'fips': '02100',
#   'risk': 2,
#   'infectionRate': 1.0,
#   'county': 'Haines Borough',
#   'vaccinationsInitiatedRatio': 0.736},
#  {'fips': '02105',
#   'risk': 0,
#   'infectionRate': None,
#   'county': 'Hoonah-Angoon Census Area',
#   'vaccinationsInitiatedRatio': 0.741},
#  {'fips': '02110',
#   'risk': 3,
#   'infectionRate': 0.72,
#   'county': 'Juneau City and Borough',
#   'vaccinationsInitiatedRatio': 0.833,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.835,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.367,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.977},
#  {'fips': '02122',
#   'risk': 2,
#   'infectionRate': 0.71,
#   'county': 'Kenai Peninsula Borough',
#   'vaccinationsInitiatedRatio': 0.535,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.724,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.136,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 1.747},
#  {'fips': '02130',
#   'risk': 2,
#   'infectionRate': 0.69,
#   'county': 'Ketchikan Gateway Borough',
#   'vaccinationsInitiatedRatio': 0.718,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.378,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.38,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.378},
#  {'fips': '02150',
#   'risk': 2,
#   'infectionRate': 0.86,
#   'county': 'Kodiak Island Borough',
#   'vaccinationsInitiatedRatio': 0.72,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.499,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.604},
#  {'fips': '02158',
#   'risk': 3,
#   'infectionRate': 1.06,
#   'county': 'Kusilvak Census Area',
#   'vaccinationsInitiatedRatio': 0.726},
#  {'fips': '02164',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'Lake and Peninsula Borough',
#   'vaccinationsInitiatedRatio': 0.635},
#  {'fips': '02170',
#   'risk': 2,
#   'infectionRate': 0.94,
#   'county': 'Matanuska-Susitna Borough',
#   'vaccinationsInitiatedRatio': 0.459,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 0.97,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.184,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 1.639},
#  {'fips': '02180',
#   'risk': 5,
#   'infectionRate': 0.88,
#   'county': 'Nome Census Area',
#   'vaccinationsInitiatedRatio': 0.739,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.762},
#  {'fips': '02185',
#   'risk': 2,
#   'infectionRate': 0.63,
#   'county': 'North Slope Borough',
#   'vaccinationsInitiatedRatio': 0.418,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.835,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 0.0},
#  {'fips': '02188',
#   'risk': 3,
#   'infectionRate': 0.63,
#   'county': 'Northwest Arctic Borough',
#   'vaccinationsInitiatedRatio': 0.65,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.59,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.59},
#  {'fips': '02195',
#   'risk': 3,
#   'infectionRate': 1.09,
#   'county': 'Petersburg Borough',
#   'vaccinationsInitiatedRatio': 0.815,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.831,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.831},
#  {'fips': '02198',
#   'risk': 1,
#   'infectionRate': 0.9,
#   'county': 'Prince of Wales-Hyder Census Area',
#   'vaccinationsInitiatedRatio': 0.585},
#  {'fips': '02220',
#   'risk': 5,
#   'infectionRate': 1.06,
#   'county': 'Sitka City and Borough',
#   'vaccinationsInitiatedRatio': 0.838,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.789,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 7.881},
#  {'fips': '02230',
#   'risk': 3,
#   'infectionRate': None,
#   'county': 'Skagway Municipality',
#   'vaccinationsInitiatedRatio': 0.783},
#  {'fips': '02240',
#   'risk': 2,
#   'infectionRate': 1.12,
#   'county': 'Southeast Fairbanks Census Area',
#   'vaccinationsInitiatedRatio': 0.457},
#  {'fips': '02261',
#   'risk': 2,
#   'infectionRate': 0.87,
#   'county': 'Valdez-Cordova Census Area',
#   'vaccinationsInitiatedRatio': 0.68,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.518,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.518},
#  {'fips': '02275',
#   'risk': 3,
#   'infectionRate': 0.77,
#   'county': 'Wrangell City and Borough',
#   'vaccinationsInitiatedRatio': 0.614,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.094,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.094},
#  {'fips': '02282',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'Yakutat City and Borough',
#   'vaccinationsInitiatedRatio': 0.819},
#  {'fips': '02290',
#   'risk': 2,
#   'infectionRate': 1.01,
#   'county': 'Yukon-Koyukuk Census Area',
#   'vaccinationsInitiatedRatio': 0.833},
#  {'fips': '01001',
#   'risk': 1,
#   'infectionRate': 0.61,
#   'county': 'Autauga County',
#   'vaccinationsInitiatedRatio': 0.555,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.336,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.146,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.064},
#  {'fips': '01003',
#   'risk': 1,
#   'infectionRate': 0.87,
#   'county': 'Baldwin County',
#   'vaccinationsInitiatedRatio': 0.642,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.176,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.307,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.32},
#  {'fips': '01005',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'Barbour County',
#   'vaccinationsInitiatedRatio': 0.556,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.563,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.261,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.856},
#  {'fips': '01007',
#   'risk': 2,
#   'infectionRate': 1.12,
#   'county': 'Bibb County',
#   'vaccinationsInitiatedRatio': 0.425,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.441,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.018},
#  {'fips': '01009',
#   'risk': 2,
#   'infectionRate': 1.13,
#   'county': 'Blount County',
#   'vaccinationsInitiatedRatio': 0.383,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 0.579,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.139,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 0.579},
#  {'fips': '01011',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Bullock County',
#   'vaccinationsInitiatedRatio': 0.672,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.841,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 7.81},
#  {'fips': '01013',
#   'risk': 1,
#   'infectionRate': 1.01,
#   'county': 'Butler County',
#   'vaccinationsInitiatedRatio': 0.496,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.439,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.471,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 6.322},
#  {'fips': '01015',
#   'risk': 0,
#   'infectionRate': 0.8,
#   'county': 'Calhoun County',
#   'vaccinationsInitiatedRatio': 0.572,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 5.156,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.277,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 6.821},
#  {'fips': '01017',
#   'risk': 1,
#   'infectionRate': 1.06,
#   'county': 'Chambers County',
#   'vaccinationsInitiatedRatio': 0.378,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.434},
#  {'fips': '01019',
#   'risk': 2,
#   'infectionRate': 1.12,
#   'county': 'Cherokee County',
#   'vaccinationsInitiatedRatio': 0.378,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.195,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.927},
#  {'fips': '01021',
#   'risk': 1,
#   'infectionRate': 0.61,
#   'county': 'Chilton County',
#   'vaccinationsInitiatedRatio': 0.442,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 0.796,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.184,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 0.918},
#  {'fips': '01023',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Choctaw County',
#   'vaccinationsInitiatedRatio': 0.819,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.493,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.493},
#  {'fips': '01025',
#   'risk': 0,
#   'infectionRate': 0.74,
#   'county': 'Clarke County',
#   'vaccinationsInitiatedRatio': 0.629,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.082,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.678},
#  {'fips': '01027',
#   'risk': 0,
#   'infectionRate': 1.01,
#   'county': 'Clay County',
#   'vaccinationsInitiatedRatio': 0.505,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.47,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.389,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.47},
#  {'fips': '01029',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Cleburne County',
#   'vaccinationsInitiatedRatio': 0.345},
#  {'fips': '01031',
#   'risk': 1,
#   'infectionRate': 1.03,
#   'county': 'Coffee County',
#   'vaccinationsInitiatedRatio': 0.587,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.573,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.182,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.405},
#  {'fips': '01033',
#   'risk': 1,
#   'infectionRate': 0.71,
#   'county': 'Colbert County',
#   'vaccinationsInitiatedRatio': 0.57,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 7.11,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.521,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 9.077},
#  {'fips': '01035',
#   'risk': 1,
#   'infectionRate': 1.08,
#   'county': 'Conecuh County',
#   'vaccinationsInitiatedRatio': 0.568,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.643,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 6.121},
#  {'fips': '01037',
#   'risk': 1,
#   'infectionRate': 1.1,
#   'county': 'Coosa County',
#   'vaccinationsInitiatedRatio': 0.488},
#  {'fips': '01039',
#   'risk': 1,
#   'infectionRate': 0.73,
#   'county': 'Covington County',
#   'vaccinationsInitiatedRatio': 0.463,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.547,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.462,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 6.643},
#  {'fips': '01041',
#   'risk': 1,
#   'infectionRate': 1.01,
#   'county': 'Crenshaw County',
#   'vaccinationsInitiatedRatio': 0.417,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.794,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 8.961},
#  {'fips': '01043',
#   'risk': 2,
#   'infectionRate': 1.19,
#   'county': 'Cullman County',
#   'vaccinationsInitiatedRatio': 0.451,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.941,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.191,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.941},
#  {'fips': '01045',
#   'risk': 1,
#   'infectionRate': 0.88,
#   'county': 'Dale County',
#   'vaccinationsInitiatedRatio': 0.571,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.101,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.164,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.428},
#  {'fips': '01047',
#   'risk': 1,
#   'infectionRate': 1.03,
#   'county': 'Dallas County',
#   'vaccinationsInitiatedRatio': 0.59,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.866,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.816,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 6.206},
#  {'fips': '01049',
#   'risk': 0,
#   'infectionRate': 0.88,
#   'county': 'DeKalb County',
#   'vaccinationsInitiatedRatio': 0.417,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.849,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.229,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.555},
#  {'fips': '01051',
#   'risk': 2,
#   'infectionRate': 0.81,
#   'county': 'Elmore County',
#   'vaccinationsInitiatedRatio': 0.575,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.131,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.081,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.084},
#  {'fips': '01053',
#   'risk': 1,
#   'infectionRate': 0.94,
#   'county': 'Escambia County',
#   'vaccinationsInitiatedRatio': 0.465,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.418,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.504,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.109},
#  {'fips': '01055',
#   'risk': 1,
#   'infectionRate': 1.05,
#   'county': 'Etowah County',
#   'vaccinationsInitiatedRatio': 0.494,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 7.543,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.716,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 9.447},
#  {'fips': '01057',
#   'risk': 1,
#   'infectionRate': 1.02,
#   'county': 'Fayette County',
#   'vaccinationsInitiatedRatio': 0.408,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.568,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.634,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.837},
#  {'fips': '01059',
#   'risk': 1,
#   'infectionRate': 1.01,
#   'county': 'Franklin County',
#   'vaccinationsInitiatedRatio': 0.533,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.222,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.305,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.443},
#  {'fips': '01061',
#   'risk': 1,
#   'infectionRate': 0.99,
#   'county': 'Geneva County',
#   'vaccinationsInitiatedRatio': 0.486,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.651,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.3,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.151},
#  {'fips': '01063',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Greene County',
#   'vaccinationsInitiatedRatio': 0.637,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.204,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.204},
#  {'fips': '01065',
#   'risk': 2,
#   'infectionRate': 1.11,
#   'county': 'Hale County',
#   'vaccinationsInitiatedRatio': 0.727,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.552,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.555},
#  {'fips': '01067',
#   'risk': 0,
#   'infectionRate': 0.87,
#   'county': 'Henry County',
#   'vaccinationsInitiatedRatio': 0.546},
#  {'fips': '01069',
#   'risk': 1,
#   'infectionRate': 0.79,
#   'county': 'Houston County',
#   'vaccinationsInitiatedRatio': 0.516,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 8.309,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.842,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 10.083},
#  {'fips': '01071',
#   'risk': 0,
#   'infectionRate': 0.97,
#   'county': 'Jackson County',
#   'vaccinationsInitiatedRatio': 0.6,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.216,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.251,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.266},
#  {'fips': '01073',
#   'risk': 1,
#   'infectionRate': 0.97,
#   'county': 'Jefferson County',
#   'vaccinationsInitiatedRatio': 0.718,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 7.503,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.968,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 9.606},
#  {'fips': '01075',
#   'risk': 1,
#   'infectionRate': 0.98,
#   'county': 'Lamar County',
#   'vaccinationsInitiatedRatio': 0.509},
#  {'fips': '01077',
#   'risk': 1,
#   'infectionRate': 0.79,
#   'county': 'Lauderdale County',
#   'vaccinationsInitiatedRatio': 0.575,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.26,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.728,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.68},
#  {'fips': '01079',
#   'risk': 1,
#   'infectionRate': 0.94,
#   'county': 'Lawrence County',
#   'vaccinationsInitiatedRatio': 0.55,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.708,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.238,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.893},
#  {'fips': '01081',
#   'risk': 1,
#   'infectionRate': 0.97,
#   'county': 'Lee County',
#   'vaccinationsInitiatedRatio': 0.48,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.93,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.297,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.12},
#  {'fips': '01083',
#   'risk': 1,
#   'infectionRate': 0.82,
#   'county': 'Limestone County',
#   'vaccinationsInitiatedRatio': 0.464,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.339,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.138,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 1.408},
#  {'fips': '01085',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Lowndes County',
#   'vaccinationsInitiatedRatio': 0.653},
#  {'fips': '01087',
#   'risk': 1,
#   'infectionRate': 0.95,
#   'county': 'Macon County',
#   'vaccinationsInitiatedRatio': 0.602,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 10.044,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 10.044},
#  {'fips': '01089',
#   'risk': 2,
#   'infectionRate': 1.12,
#   'county': 'Madison County',
#   'vaccinationsInitiatedRatio': 0.765,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.484,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.372,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.499},
#  {'fips': '01091',
#   'risk': 1,
#   'infectionRate': 0.99,
#   'county': 'Marengo County',
#   'vaccinationsInitiatedRatio': 0.67,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.583,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.349,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 6.912},
#  {'fips': '01093',
#   'risk': 0,
#   'infectionRate': 0.98,
#   'county': 'Marion County',
#   'vaccinationsInitiatedRatio': 0.427,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.227,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.349,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.229},
#  {'fips': '01095',
#   'risk': 1,
#   'infectionRate': 0.86,
#   'county': 'Marshall County',
#   'vaccinationsInitiatedRatio': 0.555,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.915,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.286,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.201},
#  {'fips': '01097',
#   'risk': 0,
#   'infectionRate': 0.64,
#   'county': 'Mobile County',
#   'vaccinationsInitiatedRatio': 0.605,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 5.342,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.512,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 6.61},
#  {'fips': '01099',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Monroe County',
#   'vaccinationsInitiatedRatio': 0.547,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.064,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.5,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.878},
#  {'fips': '01101',
#   'risk': 1,
#   'infectionRate': 0.83,
#   'county': 'Montgomery County',
#   'vaccinationsInitiatedRatio': 0.66,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 6.448,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.54,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 7.924},
#  {'fips': '01103',
#   'risk': 1,
#   'infectionRate': 0.93,
#   'county': 'Morgan County',
#   'vaccinationsInitiatedRatio': 0.514,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.24,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.381,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.984},
#  {'fips': '01105',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'Perry County',
#   'vaccinationsInitiatedRatio': 0.585},
#  {'fips': '01107',
#   'risk': 1,
#   'infectionRate': 0.98,
#   'county': 'Pickens County',
#   'vaccinationsInitiatedRatio': 0.608,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.569,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.257,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.597},
#  {'fips': '01109',
#   'risk': 1,
#   'infectionRate': 0.83,
#   'county': 'Pike County',
#   'vaccinationsInitiatedRatio': 0.511,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.864,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.359,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.864},
#  {'fips': '01111',
#   'risk': 1,
#   'infectionRate': 0.99,
#   'county': 'Randolph County',
#   'vaccinationsInitiatedRatio': 0.403,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 1.973},
#  {'fips': '01113',
#   'risk': 1,
#   'infectionRate': 0.94,
#   'county': 'Russell County',
#   'vaccinationsInitiatedRatio': 0.553},
#  {'fips': '01115',
#   'risk': 1,
#   'infectionRate': 0.83,
#   'county': 'St. Clair County',
#   'vaccinationsInitiatedRatio': 0.467,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 0.599,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.09,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 0.599},
#  {'fips': '01117',
#   'risk': 1,
#   'infectionRate': 0.92,
#   'county': 'Shelby County',
#   'vaccinationsInitiatedRatio': 0.449,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.326,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.2,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.182},
#  {'fips': '01119',
#   'risk': 0,
#   'infectionRate': 0.99,
#   'county': 'Sumter County',
#   'vaccinationsInitiatedRatio': 0.682,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.427,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.427},
#  {'fips': '01121',
#   'risk': 1,
#   'infectionRate': 0.79,
#   'county': 'Talladega County',
#   'vaccinationsInitiatedRatio': 0.444,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.392,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.229,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.752},
#  {'fips': '01123',
#   'risk': 2,
#   'infectionRate': 1.14,
#   'county': 'Tallapoosa County',
#   'vaccinationsInitiatedRatio': 0.456,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.556,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.192,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.058},
#  {'fips': '01125',
#   'risk': 1,
#   'infectionRate': 0.9,
#   'county': 'Tuscaloosa County',
#   'vaccinationsInitiatedRatio': 0.528,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.569,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.542,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.441},
#  {'fips': '01127',
#   'risk': 1,
#   'infectionRate': 0.56,
#   'county': 'Walker County',
#   'vaccinationsInitiatedRatio': 0.564,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.288,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.249,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.531},
#  {'fips': '01129',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Washington County',
#   'vaccinationsInitiatedRatio': 0.558,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.211,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.019},
#  {'fips': '01131',
#   'risk': 3,
#   'infectionRate': 1.11,
#   'county': 'Wilcox County',
#   'vaccinationsInitiatedRatio': 0.673,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.691,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.845},
#  {'fips': '01133',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Winston County',
#   'vaccinationsInitiatedRatio': 0.264,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.672,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.218,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.672},
#  {'fips': '05001',
#   'risk': 1,
#   'infectionRate': 0.97,
#   'county': 'Arkansas County',
#   'vaccinationsInitiatedRatio': 0.65,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 5.551,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.551},
#  {'fips': '05003',
#   'risk': 0,
#   'infectionRate': 0.99,
#   'county': 'Ashley County',
#   'vaccinationsInitiatedRatio': 0.584,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.663,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.399,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.195},
#  {'fips': '05005',
#   'risk': 1,
#   'infectionRate': 0.87,
#   'county': 'Baxter County',
#   'vaccinationsInitiatedRatio': 0.548,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 5.066,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.507,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 7.986},
#  {'fips': '05007',
#   'risk': 1,
#   'infectionRate': 0.82,
#   'county': 'Benton County',
#   'vaccinationsInitiatedRatio': 0.649,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.413,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.154,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.23},
#  {'fips': '05009',
#   'risk': 1,
#   'infectionRate': 0.77,
#   'county': 'Boone County',
#   'vaccinationsInitiatedRatio': 0.442,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.262,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.852,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 6.18},
#  {'fips': '05011',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Bradley County',
#   'vaccinationsInitiatedRatio': 0.671,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.101,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.093},
#  {'fips': '05013',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'Calhoun County',
#   'vaccinationsInitiatedRatio': 0.432},
#  {'fips': '05015',
#   'risk': 1,
#   'infectionRate': 0.83,
#   'county': 'Carroll County',
#   'vaccinationsInitiatedRatio': 0.573,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.858,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 1.858},
#  {'fips': '05017',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Chicot County',
#   'vaccinationsInitiatedRatio': 0.657,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.173,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.077},
#  {'fips': '05019',
#   'risk': 1,
#   'infectionRate': 0.83,
#   'county': 'Clark County',
#   'vaccinationsInitiatedRatio': 0.567,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.531,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 1.531},
#  {'fips': '05021',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Clay County',
#   'vaccinationsInitiatedRatio': 0.518,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.21,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.21},
#  {'fips': '05023',
#   'risk': 1,
#   'infectionRate': 0.86,
#   'county': 'Cleburne County',
#   'vaccinationsInitiatedRatio': 0.517,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 1.264},
#  {'fips': '05025',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Cleveland County',
#   'vaccinationsInitiatedRatio': 0.607},
#  {'fips': '05027',
#   'risk': 1,
#   'infectionRate': 0.97,
#   'county': 'Columbia County',
#   'vaccinationsInitiatedRatio': 0.584,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.744,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.349,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.849},
#  {'fips': '05029',
#   'risk': 1,
#   'infectionRate': 1.03,
#   'county': 'Conway County',
#   'vaccinationsInitiatedRatio': 0.618,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.585,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 1.585},
#  {'fips': '05031',
#   'risk': 1,
#   'infectionRate': 0.38,
#   'county': 'Craighead County',
#   'vaccinationsInitiatedRatio': 0.538,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 7.554,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.847,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 9.568},
#  {'fips': '05033',
#   'risk': 0,
#   'infectionRate': 0.76,
#   'county': 'Crawford County',
#   'vaccinationsInitiatedRatio': 0.536,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 0.84,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.172,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.218},
#  {'fips': '05035',
#   'risk': 0,
#   'infectionRate': 0.41,
#   'county': 'Crittenden County',
#   'vaccinationsInitiatedRatio': 0.547,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.529,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 1.588},
#  {'fips': '05037',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Cross County',
#   'vaccinationsInitiatedRatio': 0.589,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.212,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.019},
#  {'fips': '05039',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Dallas County',
#   'vaccinationsInitiatedRatio': 0.646,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.995,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.54},
#  {'fips': '05041',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Desha County',
#   'vaccinationsInitiatedRatio': 0.718,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 6.015,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 6.015},
#  {'fips': '05043',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'Drew County',
#   'vaccinationsInitiatedRatio': 0.563,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.587,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.366,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.587},
#  {'fips': '05045',
#   'risk': 1,
#   'infectionRate': 0.81,
#   'county': 'Faulkner County',
#   'vaccinationsInitiatedRatio': 0.596,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.995,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.272,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.125},
#  {'fips': '05047',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Franklin County',
#   'vaccinationsInitiatedRatio': 0.543,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.879,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 1.879},
#  {'fips': '05049',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Fulton County',
#   'vaccinationsInitiatedRatio': 0.381,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.631,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.631},
#  {'fips': '05051',
#   'risk': 1,
#   'infectionRate': 0.64,
#   'county': 'Garland County',
#   'vaccinationsInitiatedRatio': 0.539,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 5.484,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.532,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 7.286},
#  {'fips': '05053',
#   'risk': 1,
#   'infectionRate': 0.96,
#   'county': 'Grant County',
#   'vaccinationsInitiatedRatio': 0.533},
#  {'fips': '05055',
#   'risk': 1,
#   'infectionRate': 0.93,
#   'county': 'Greene County',
#   'vaccinationsInitiatedRatio': 0.495,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.435,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.241,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.887},
#  {'fips': '05057',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'Hempstead County',
#   'vaccinationsInitiatedRatio': 0.498,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.29,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.512,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.059},
#  {'fips': '05059',
#   'risk': 1,
#   'infectionRate': 0.93,
#   'county': 'Hot Spring County',
#   'vaccinationsInitiatedRatio': 0.487,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.456,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.23,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.837},
#  {'fips': '05061',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Howard County',
#   'vaccinationsInitiatedRatio': 0.64,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.612,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.612},
#  {'fips': '05063',
#   'risk': 1,
#   'infectionRate': 0.99,
#   'county': 'Independence County',
#   'vaccinationsInitiatedRatio': 0.482,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 6.677,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.435,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 8.527},
#  {'fips': '05065',
#   'risk': 1,
#   'infectionRate': 1.01,
#   'county': 'Izard County',
#   'vaccinationsInitiatedRatio': 0.444,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.293,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.293},
#  {'fips': '05067',
#   'risk': 2,
#   'infectionRate': 0.83,
#   'county': 'Jackson County',
#   'vaccinationsInitiatedRatio': 0.456,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 10.134},
#  {'fips': '05069',
#   'risk': 1,
#   'infectionRate': 1.09,
#   'county': 'Jefferson County',
#   'vaccinationsInitiatedRatio': 0.562,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 5.323,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.668,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 9.782},
#  {'fips': '05071',
#   'risk': 1,
#   'infectionRate': 0.84,
#   'county': 'Johnson County',
#   'vaccinationsInitiatedRatio': 0.581,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.952,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.414,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.662},
#  {'fips': '05073',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'Lafayette County',
#   'vaccinationsInitiatedRatio': 0.496},
#  {'fips': '05075',
#   'risk': 1,
#   'infectionRate': 0.58,
#   'county': 'Lawrence County',
#   'vaccinationsInitiatedRatio': 0.551,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.026,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.026},
#  {'fips': '05077',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Lee County',
#   'vaccinationsInitiatedRatio': 0.431},
#  {'fips': '05079',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'Lincoln County',
#   'vaccinationsInitiatedRatio': 0.422},
#  {'fips': '05081',
#   'risk': 1,
#   'infectionRate': 0.95,
#   'county': 'Little River County',
#   'vaccinationsInitiatedRatio': 0.494,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.68,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.68},
#  {'fips': '05083',
#   'risk': 1,
#   'infectionRate': 0.93,
#   'county': 'Logan County',
#   'vaccinationsInitiatedRatio': 0.538,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.42,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.481},
#  {'fips': '05085',
#   'risk': 1,
#   'infectionRate': 0.86,
#   'county': 'Lonoke County',
#   'vaccinationsInitiatedRatio': 0.556},
#  {'fips': '05087',
#   'risk': 1,
#   'infectionRate': 0.76,
#   'county': 'Madison County',
#   'vaccinationsInitiatedRatio': 0.503},
#  {'fips': '05089',
#   'risk': 1,
#   'infectionRate': 0.8,
#   'county': 'Marion County',
#   'vaccinationsInitiatedRatio': 0.424},
#  {'fips': '05091',
#   'risk': 1,
#   'infectionRate': 0.71,
#   'county': 'Miller County',
#   'vaccinationsInitiatedRatio': 0.417,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.546,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 1.917},
#  {'fips': '05093',
#   'risk': 1,
#   'infectionRate': 0.42,
#   'county': 'Mississippi County',
#   'vaccinationsInitiatedRatio': 0.485,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.969,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.17,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.209},
#  {'fips': '05095',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Monroe County',
#   'vaccinationsInitiatedRatio': 0.688},
#  {'fips': '05097',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Montgomery County',
#   'vaccinationsInitiatedRatio': 0.428},
#  {'fips': '05099',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'Nevada County',
#   'vaccinationsInitiatedRatio': 0.567},
#  {'fips': '05101',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'Newton County',
#   'vaccinationsInitiatedRatio': 0.407},
#  {'fips': '05103',
#   'risk': 1,
#   'infectionRate': 0.85,
#   'county': 'Ouachita County',
#   'vaccinationsInitiatedRatio': 0.625,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.601,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.449,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.498},
#  {'fips': '05105',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Perry County',
#   'vaccinationsInitiatedRatio': 0.601},
#  {'fips': '05107',
#   'risk': 2,
#   'infectionRate': 1.15,
#   'county': 'Phillips County',
#   'vaccinationsInitiatedRatio': 0.588,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 9.815,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.464,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 11.978},
#  {'fips': '05109',
#   'risk': 1,
#   'infectionRate': 0.99,
#   'county': 'Pike County',
#   'vaccinationsInitiatedRatio': 0.519},
#  {'fips': '05111',
#   'risk': 1,
#   'infectionRate': 0.81,
#   'county': 'Poinsett County',
#   'vaccinationsInitiatedRatio': 0.53},
#  {'fips': '05113',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'Polk County',
#   'vaccinationsInitiatedRatio': 0.437,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.727,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.399,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.324},
#  {'fips': '05115',
#   'risk': 1,
#   'infectionRate': 0.77,
#   'county': 'Pope County',
#   'vaccinationsInitiatedRatio': 0.576,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.93,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.235,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.636},
#  {'fips': '05117',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Prairie County',
#   'vaccinationsInitiatedRatio': 0.521},
#  {'fips': '05119',
#   'risk': 1,
#   'infectionRate': 0.98,
#   'county': 'Pulaski County',
#   'vaccinationsInitiatedRatio': 0.686,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 12.488,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.959,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 15.361},
#  {'fips': '05121',
#   'risk': 1,
#   'infectionRate': 0.82,
#   'county': 'Randolph County',
#   'vaccinationsInitiatedRatio': 0.49,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.403,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.15,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.754},
#  {'fips': '05123',
#   'risk': 0,
#   'infectionRate': 0.78,
#   'county': 'St. Francis County',
#   'vaccinationsInitiatedRatio': 0.593,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.867,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.307,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 6.041},
#  {'fips': '05125',
#   'risk': 1,
#   'infectionRate': 0.84,
#   'county': 'Saline County',
#   'vaccinationsInitiatedRatio': 0.587,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.282,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.176,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.834},
#  {'fips': '05127',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Scott County',
#   'vaccinationsInitiatedRatio': 0.572,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.11,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.11},
#  {'fips': '05129',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Searcy County',
#   'vaccinationsInitiatedRatio': 0.453},
#  {'fips': '05131',
#   'risk': 1,
#   'infectionRate': 0.71,
#   'county': 'Sebastian County',
#   'vaccinationsInitiatedRatio': 0.6,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 6.108,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.329,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 11.737},
#  {'fips': '05133',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'Sevier County',
#   'vaccinationsInitiatedRatio': 0.533,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.963},
#  {'fips': '05135',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Sharp County',
#   'vaccinationsInitiatedRatio': 0.46},
#  {'fips': '05137',
#   'risk': 1,
#   'infectionRate': 0.98,
#   'county': 'Stone County',
#   'vaccinationsInitiatedRatio': 0.423,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.542,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.542},
#  {'fips': '05139',
#   'risk': 1,
#   'infectionRate': 1.08,
#   'county': 'Union County',
#   'vaccinationsInitiatedRatio': 0.614,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.847,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.555,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.753},
#  {'fips': '05141',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Van Buren County',
#   'vaccinationsInitiatedRatio': 0.475,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 1.931},
#  {'fips': '05143',
#   'risk': 1,
#   'infectionRate': 0.86,
#   'county': 'Washington County',
#   'vaccinationsInitiatedRatio': 0.668,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 5.128,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.36,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 6.844},
#  {'fips': '05145',
#   'risk': 1,
#   'infectionRate': 0.7,
#   'county': 'White County',
#   'vaccinationsInitiatedRatio': 0.517,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.015,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.225,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 8.048},
#  {'fips': '05147',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Woodruff County',
#   'vaccinationsInitiatedRatio': 0.646},
#  {'fips': '05149',
#   'risk': 0,
#   'infectionRate': 0.9,
#   'county': 'Yell County',
#   'vaccinationsInitiatedRatio': 0.556,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.495,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.829},
#  {'fips': '04001',
#   'risk': 2,
#   'infectionRate': 1.05,
#   'county': 'Apache County',
#   'vaccinationsInitiatedRatio': 0.95,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.228,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.228},
#  {'fips': '04003',
#   'risk': 1,
#   'infectionRate': 0.93,
#   'county': 'Cochise County',
#   'vaccinationsInitiatedRatio': 0.801,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.409,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.125,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 1.67},
#  {'fips': '04005',
#   'risk': 1,
#   'infectionRate': 0.98,
#   'county': 'Coconino County',
#   'vaccinationsInitiatedRatio': 0.907,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.411,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.393,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.622},
#  {'fips': '04007',
#   'risk': 2,
#   'infectionRate': 1.03,
#   'county': 'Gila County',
#   'vaccinationsInitiatedRatio': 0.689,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.189,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.19,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 1.189},
#  {'fips': '04009',
#   'risk': 3,
#   'infectionRate': 1.41,
#   'county': 'Graham County',
#   'vaccinationsInitiatedRatio': 0.73,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.148,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 6.632},
#  {'fips': '04011',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'Greenlee County',
#   'vaccinationsInitiatedRatio': 0.493},
#  {'fips': '04012',
#   'risk': 2,
#   'infectionRate': 1.36,
#   'county': 'La Paz County',
#   'vaccinationsInitiatedRatio': 0.602,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.615,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.174,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.615},
#  {'fips': '04013',
#   'risk': 1,
#   'infectionRate': 1.07,
#   'county': 'Maricopa County',
#   'vaccinationsInitiatedRatio': 0.67,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.128,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.284,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.663},
#  {'fips': '04015',
#   'risk': 1,
#   'infectionRate': 0.94,
#   'county': 'Mohave County',
#   'vaccinationsInitiatedRatio': 0.507,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.238,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.47,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.585},
#  {'fips': '04017',
#   'risk': 1,
#   'infectionRate': 0.95,
#   'county': 'Navajo County',
#   'vaccinationsInitiatedRatio': 0.921,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.252,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.154,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.405},
#  {'fips': '04019',
#   'risk': 2,
#   'infectionRate': 1.22,
#   'county': 'Pima County',
#   'vaccinationsInitiatedRatio': 0.82,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.48,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.375,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.209},
#  {'fips': '04021',
#   'risk': 3,
#   'infectionRate': 1.27,
#   'county': 'Pinal County',
#   'vaccinationsInitiatedRatio': 0.624,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.193,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.071,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 1.193},
#  {'fips': '04023',
#   'risk': 1,
#   'infectionRate': 0.97,
#   'county': 'Santa Cruz County',
#   'vaccinationsInitiatedRatio': None,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 0.765,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 0.765},
#  {'fips': '04025',
#   'risk': 1,
#   'infectionRate': 0.85,
#   'county': 'Yavapai County',
#   'vaccinationsInitiatedRatio': 0.569,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.861,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.206,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.299},
#  {'fips': '04027',
#   'risk': 1,
#   'infectionRate': 0.7,
#   'county': 'Yuma County',
#   'vaccinationsInitiatedRatio': 0.886,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.997,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.275,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.997},
#  {'fips': '06001',
#   'risk': 2,
#   'infectionRate': 1.29,
#   'county': 'Alameda County',
#   'vaccinationsInitiatedRatio': 0.877,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.772,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.251,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.407},
#  {'fips': '06003',
#   'risk': 0,
#   'infectionRate': None,
#   'county': 'Alpine County',
#   'vaccinationsInitiatedRatio': 0.758},
#  {'fips': '06005',
#   'risk': 0,
#   'infectionRate': 0.86,
#   'county': 'Amador County',
#   'vaccinationsInitiatedRatio': 0.624,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.584,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.183,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 1.584},
#  {'fips': '06007',
#   'risk': 1,
#   'infectionRate': 0.78,
#   'county': 'Butte County',
#   'vaccinationsInitiatedRatio': 0.578,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.66,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.243,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.62},
#  {'fips': '06009',
#   'risk': 1,
#   'infectionRate': 1.08,
# ...
#   'vaccinationsInitiatedRatio': 0.704,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 0.762,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.166,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 1.657},
#  {'fips': '20105',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'Lincoln County',
#   'vaccinationsInitiatedRatio': 0.475,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.399,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 6.159},
#  {'fips': '20107',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'Linn County',
#   'vaccinationsInitiatedRatio': 0.396},
#  {'fips': '20109',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Logan County',
#   'vaccinationsInitiatedRatio': 0.515,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 11.876,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 11.876},
#  {'fips': '20111',
#   'risk': 2,
#   'infectionRate': 1.21,
#   'county': 'Lyon County',
#   'vaccinationsInitiatedRatio': 0.642,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 0.855,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.244,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 1.018},
#  {'fips': '20113',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'McPherson County',
#   'vaccinationsInitiatedRatio': 0.615,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.811,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.329,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.47},
#  {'fips': '20115',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Marion County',
#   'vaccinationsInitiatedRatio': 0.552,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.765,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.765},
#  {'fips': '20117',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Marshall County',
#   'vaccinationsInitiatedRatio': 0.699,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.191,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.468},
#  {'fips': '20119',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Meade County',
#   'vaccinationsInitiatedRatio': 0.525,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 6.75,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 6.75},
#  {'fips': '20121',
#   'risk': 3,
#   'infectionRate': 1.53,
#   'county': 'Miami County',
#   'vaccinationsInitiatedRatio': 0.541,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 7.225,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 4.302,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 9.944},
#  {'fips': '20123',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Mitchell County',
#   'vaccinationsInitiatedRatio': 0.559,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.551,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.888,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.548},
#  {'fips': '20125',
#   'risk': 2,
#   'infectionRate': 1.16,
#   'county': 'Montgomery County',
#   'vaccinationsInitiatedRatio': 0.529,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.006,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.299,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.006},
#  {'fips': '20127',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Morris County',
#   'vaccinationsInitiatedRatio': 0.615,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 5.842,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.842},
#  {'fips': '20129',
#   'risk': 0,
#   'infectionRate': None,
#   'county': 'Morton County',
#   'vaccinationsInitiatedRatio': 0.479,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 13.299,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 14.322},
#  {'fips': '20131',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'Nemaha County',
#   'vaccinationsInitiatedRatio': 0.58,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 5.64,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 6.741},
#  {'fips': '20133',
#   'risk': 2,
#   'infectionRate': 1.01,
#   'county': 'Neosho County',
#   'vaccinationsInitiatedRatio': 0.339,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.905,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.433,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.164},
#  {'fips': '20135',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'Ness County',
#   'vaccinationsInitiatedRatio': 0.589,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 17.106,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 23.116},
#  {'fips': '20137',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Norton County',
#   'vaccinationsInitiatedRatio': 0.543,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 5.817,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.817},
#  {'fips': '20139',
#   'risk': 2,
#   'infectionRate': 1.22,
#   'county': 'Osage County',
#   'vaccinationsInitiatedRatio': 0.568},
#  {'fips': '20141',
#   'risk': 3,
#   'infectionRate': 1.0,
#   'county': 'Osborne County',
#   'vaccinationsInitiatedRatio': 0.457,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 8.889,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 9.259},
#  {'fips': '20143',
#   'risk': 2,
#   'infectionRate': 1.0,
#   'county': 'Ottawa County',
#   'vaccinationsInitiatedRatio': 0.509,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 5.754,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.754},
#  {'fips': '20145',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'Pawnee County',
#   'vaccinationsInitiatedRatio': 0.581,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 22.839,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 120.423},
#  {'fips': '20147',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'Phillips County',
#   'vaccinationsInitiatedRatio': 0.473,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 6.269,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 6.269},
#  {'fips': '20149',
#   'risk': 2,
#   'infectionRate': 1.3,
#   'county': 'Pottawatomie County',
#   'vaccinationsInitiatedRatio': 0.464,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.588,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.009},
#  {'fips': '20151',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'Pratt County',
#   'vaccinationsInitiatedRatio': 0.56,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 5.18,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.888,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.18},
#  {'fips': '20153',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Rawlins County',
#   'vaccinationsInitiatedRatio': 0.462,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 7.748,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 12.397},
#  {'fips': '20155',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Reno County',
#   'vaccinationsInitiatedRatio': 0.551,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 2.929,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.385,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.277},
#  {'fips': '20157',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Republic County',
#   'vaccinationsInitiatedRatio': 0.546,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 6.912,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 6.912},
#  {'fips': '20159',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Rice County',
#   'vaccinationsInitiatedRatio': 0.494,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.582,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 3.582},
#  {'fips': '20161',
#   'risk': 1,
#   'infectionRate': 0.81,
#   'county': 'Riley County',
#   'vaccinationsInitiatedRatio': 0.445,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.77,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.143,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 2.914},
#  {'fips': '20163',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Rooks County',
#   'vaccinationsInitiatedRatio': 0.522,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.217,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.271},
#  {'fips': '20165',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Rush County',
#   'vaccinationsInitiatedRatio': 0.565,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 6.723,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 10.504},
#  {'fips': '20167',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'Russell County',
#   'vaccinationsInitiatedRatio': 0.479,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.592,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.726},
#  {'fips': '20169',
#   'risk': 2,
#   'infectionRate': 1.2,
#   'county': 'Saline County',
#   'vaccinationsInitiatedRatio': 0.567,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.726,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.445,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 9.7},
#  {'fips': '20171',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Scott County',
#   'vaccinationsInitiatedRatio': 0.529,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 7.203,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 7.203},
#  {'fips': '20173',
#   'risk': 2,
#   'infectionRate': 1.12,
#   'county': 'Sedgwick County',
#   'vaccinationsInitiatedRatio': 0.666,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.414,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.661,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 7.497},
#  {'fips': '20175',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'Seward County',
#   'vaccinationsInitiatedRatio': 0.631,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 5.008,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.564,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.008},
#  {'fips': '20177',
#   'risk': 1,
#   'infectionRate': 1.1,
#   'county': 'Shawnee County',
#   'vaccinationsInitiatedRatio': 0.702,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 5.7,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.396,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 8.131},
#  {'fips': '20179',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'Sheridan County',
#   'vaccinationsInitiatedRatio': 0.392,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 9.746,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 9.746},
#  {'fips': '20181',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Sherman County',
#   'vaccinationsInitiatedRatio': 0.485,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.83,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.75},
#  {'fips': '20183',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Smith County',
#   'vaccinationsInitiatedRatio': 0.482,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 0.0,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 18.895},
#  {'fips': '20185',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'Stafford County',
#   'vaccinationsInitiatedRatio': 0.514,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 8.109,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 8.109},
#  {'fips': '20187',
#   'risk': 0,
#   'infectionRate': None,
#   'county': 'Stanton County',
#   'vaccinationsInitiatedRatio': 0.56,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 11.453,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 12.885},
#  {'fips': '20189',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Stevens County',
#   'vaccinationsInitiatedRatio': 0.446,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.46,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 6.558},
#  {'fips': '20191',
#   'risk': 2,
#   'infectionRate': 1.25,
#   'county': 'Sumner County',
#   'vaccinationsInitiatedRatio': 0.49,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.981,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.111},
#  {'fips': '20193',
#   'risk': 2,
#   'infectionRate': 1.0,
#   'county': 'Thomas County',
#   'vaccinationsInitiatedRatio': 0.464,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.782,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.18,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 4.503},
#  {'fips': '20195',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'Trego County',
#   'vaccinationsInitiatedRatio': 0.414,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 11.176,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 11.176},
#  {'fips': '20197',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Wabaunsee County',
#   'vaccinationsInitiatedRatio': 0.516},
#  {'fips': '20199',
#   'risk': 1,
#   'infectionRate': None,
#   'county': 'Wallace County',
#   'vaccinationsInitiatedRatio': 0.391},
#  {'fips': '20201',
#   'risk': 2,
#   'infectionRate': 1.0,
#   'county': 'Washington County',
#   'vaccinationsInitiatedRatio': 0.585,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 12.189,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 12.189},
#  {'fips': '20203',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'Wichita County',
#   'vaccinationsInitiatedRatio': 0.541,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 16.745,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 16.745},
#  {'fips': '20205',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'Wilson County',
#   'vaccinationsInitiatedRatio': 0.484,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 6.26,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 6.26},
#  {'fips': '20207',
#   'risk': 0,
#   'infectionRate': 1.0,
#   'county': 'Woodson County',
#   'vaccinationsInitiatedRatio': 0.476},
#  {'fips': '20209',
#   'risk': 2,
#   'infectionRate': 1.19,
#   'county': 'Wyandotte County',
#   'vaccinationsInitiatedRatio': 0.7,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 9.17,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 1.117,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 11.915},
#  {'fips': '21001',
#   'risk': 1,
#   'infectionRate': 0.55,
#   'county': 'Adair County',
#   'vaccinationsInitiatedRatio': 0.443,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.373,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.3},
#  {'fips': '21003',
#   'risk': 1,
#   'infectionRate': 1.0,
#   'county': 'Allen County',
#   'vaccinationsInitiatedRatio': 0.442,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 1.584,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.0,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 1.584},
#  {'fips': '21005',
#   'risk': 2,
#   'infectionRate': 0.56,
#   'county': 'Anderson County',
#   'vaccinationsInitiatedRatio': 0.639},
#  {'fips': '21007',
#   'risk': 3,
#   'infectionRate': 0.75,
#   'county': 'Ballard County',
#   'vaccinationsInitiatedRatio': 0.422},
#  {'fips': '21009',
#   'risk': 0,
#   'infectionRate': 0.86,
#   'county': 'Barren County',
#   'vaccinationsInitiatedRatio': 0.516,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 3.287,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.304,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 5.478},
#  {'fips': '21011',
#   'risk': 3,
#   'infectionRate': 0.79,
#   'county': 'Bath County',
#   'vaccinationsInitiatedRatio': 0.599},
#  {'fips': '21013',
#   'risk': 1,
#   'infectionRate': 0.81,
#   'county': 'Bell County',
#   'vaccinationsInitiatedRatio': 0.526,
#   'Staffed All Beds [Per 1000 Adults (20+)]': 4.27,
#   'Staffed ICU Beds [Per 1000 Adults (20+)]': 0.344,
#   'Licensed All Beds [Per 1000 Adults (20+)]': 10.601},
#  ...]

# %%
#final json file
import json
with open('hospitalandrisk.json', 'w') as f:
    json.dump(dataR, f)
